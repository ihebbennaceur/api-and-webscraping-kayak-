# %%
import requests
import pandas as pd
import json
import plotly.io as pio
import plotly.express as px

# %%
villes=["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",]
# "Rouen",
# "Paris",
# "Amiens",
# "Lille",
# "Strasbourg",
# "Chateau du Haut Koenigsbourg",
# "Colmar",
# "Eguisheim",
# "Besancon",
# "Dijon",
# "Annecy",
# "Grenoble",
# "Lyon",
# "Gorges du Verdon",
# "Bormes les Mimosas",
# "Cassis",
# "Marseille",
# "Aix en Provence",
# "Avignon",
# "Uzes",
# "Nimes",
# "Aigues Mortes",
# "Saintes Maries de la mer",
# "Collioure",
# "Carcassonne",
# "Ariege",
# "Toulouse",
# "Montauban",
# "Biarritz",
# "Bayonne",
# "La Rochelle"]

# %% [markdown]
# # ***API calls per day are limited  ***

# %%
rez=[]
for i in range(len(villes)):
  r=requests.get("https://nominatim.openstreetmap.org/search?",params={'city':villes[i],'format':'json','country':'france'})
  rez.append(r.json())

# %%
rez
# Out:
# [[{'place_id': 156604934,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 211285890,
#    'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'],
#    'lat': '48.6359541',
#    'lon': '-1.511459954959514',
#    'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France',
#    'class': 'place',
#    'type': 'islet',
#    'importance': 0.855436556781574}],
#  [{'place_id': 298187446,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 905534,
#    'boundingbox': ['48.5979853', '48.6949736', '-2.0765246', '-1.9367259'],
#    'lat': '48.649518',
#    'lon': '-2.0260409',
#    'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.7764672172428952,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#   {'place_id': 298319921,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 1653637,
#    'boundingbox': ['48.266957', '48.7220079', '-2.1619838', '-1.4850797'],
#    'lat': '48.4904728',
#    'lon': '-1.7421554637978962',
#    'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.6572742271829002,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#   {'place_id': 338788269,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 9917850021,
#    'boundingbox': ['47.5783644', '47.5983644', '0.91302', '0.93302'],
#    'lat': '47.5883644',
#    'lon': '0.92302',
#    'display_name': 'Saint-Malo, La Bonleuvre, Auzouer-en-Touraine, Loches, Indre-et-Loire, Centre-Val de Loire, France métropolitaine, 37110, France',
#    'class': 'place',
#    'type': 'neighbourhood',
#    'importance': 0.45000999999999997},
#   {'place_id': 6048349,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 739408809,
#    'boundingbox': ['47.7893339', '47.8293339', '-1.5497978', '-1.5097978'],
#    'lat': '47.8093339',
#    'lon': '-1.5297978',
#    'display_name': 'Saint-Malo, Teillay, Redon, Ille-et-Vilaine, Bretagne, France métropolitaine, 35620, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.45,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 49547994,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 4381382983,
#    'boundingbox': ['47.9180971', '47.9580971', '-2.4312551', '-2.3912551'],
#    'lat': '47.9380971',
#    'lon': '-2.4112551',
#    'display_name': 'Saint-Malo, Ploërmel, Pontivy, Morbihan, Bretagne, France métropolitaine, 56800, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.45,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 50172493,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 4419648415,
#    'boundingbox': ['47.9559266', '47.9959266', '-2.3969864', '-2.3569864'],
#    'lat': '47.9759266',
#    'lon': '-2.3769864',
#    'display_name': 'Saint-Malo, Loyat, Pontivy, Morbihan, Bretagne, France métropolitaine, 56800, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.45,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 49747496,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 4346569622,
#    'boundingbox': ['47.5168163', '47.5568163', '-2.1739705', '-2.1339705'],
#    'lat': '47.5368163',
#    'lon': '-2.1539705',
#    'display_name': 'Saint-Malo, Saint-Dolay, Vannes, Morbihan, Bretagne, France métropolitaine, 56130, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.45,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 342419537,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 10009043996,
#    'boundingbox': ['47.2817513', '47.3217513', '0.7806012', '0.8206012'],
#    'lat': '47.3017513',
#    'lon': '0.8006012',
#    'display_name': 'Saint-Malo, Esvres, Arrondissement de Tours, Indre-et-Loire, Centre-Val de Loire, France métropolitaine, 37320, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.45,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 6174909,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 798178453,
#    'boundingbox': ['48.7147563', '48.7547563', '-0.2609271', '-0.2209271'],
#    'lat': '48.7347563',
#    'lon': '-0.2409271',
#    'display_name': 'Saint-Mâlo, La Fresnaye-au-Sauvage, Putanges-le-Lac, Argentan, Orne, Normandie, France métropolitaine, 61210, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.35,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 338433599,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 9909225864,
#    'boundingbox': ['49.2821442', '49.2822442', '-0.9507235', '-0.9506235'],
#    'lat': '49.2821942',
#    'lon': '-0.9506735',
#    'display_name': 'Saint-Mâlo, Bricqueville, Bayeux, Calvados, Normandie, France métropolitaine, 14710, France',
#    'class': 'place',
#    'type': 'isolated_dwelling',
#    'importance': 0.29999999999999993}],
#  [{'place_id': 298563984,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 145776,
#    'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378'],
#    'lat': '49.2764624',
#    'lon': '-0.7024738',
#    'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.7827003853621928,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#   {'place_id': 298371637,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 1656892,
#    'boundingbox': ['49.0931773', '49.3978952', '-1.1412392', '-0.4113237'],
#    'lat': '49.2455634',
#    'lon': '-0.7916770441791112',
#    'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.5869371059968022,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}],
#  [{'place_id': 297969319,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 104492,
#    'boundingbox': ['49.4516697', '49.5401463', '0.0667992', '0.1955556'],
#    'lat': '49.4938975',
#    'lon': '0.1079732',
#    'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.9223325741883645,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#   {'place_id': 298735809,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 3012370,
#    'boundingbox': ['49.4287837', '49.826254', '0.0657702', '0.6917633'],
#    'lat': '49.627549200000004',
#    'lon': '0.3921241327294534',
#    'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France',
#    'class': 'boundary',
#    'type': 'administrative',
#    'importance': 0.6752824455605189,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#   {'place_id': 46354396,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 3918888890,
#    'boundingbox': ['48.1371505', '48.1771505', '-1.7514713', '-1.7114713'],
#    'lat': '48.1571505',
#    'lon': '-1.7314713',
#    'display_name': 'Le Havre, Montgermont, Rennes, Ille-et-Vilaine, Bretagne, France métropolitaine, 35760, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.55001,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 96283622,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 9445672954,
#    'boundingbox': ['49.1480287', '49.1880287', '-0.2284173', '-0.1884173'],
#    'lat': '49.1680287',
#    'lon': '-0.2084173',
#    'display_name': 'Le Havre, Banneville-la-Campagne, Caen, Calvados, Normandie, France métropolitaine, 14940, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.55,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 35418385,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 2934385149,
#    'boundingbox': ['48.5361794', '48.5761794', '-1.9047792', '-1.8647792'],
#    'lat': '48.5561794',
#    'lon': '-1.8847792',
#    'display_name': 'Le Havre, Miniac-Morvan, Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35540, France',
#    'class': 'place',
#    'type': 'hamlet',
#    'importance': 0.55,
#    'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'},
#   {'place_id': 24980084,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 2696215787,
#    'boundingbox': ['48.4308301', '48.4309301', '-2.5484416', '-2.5483416'],
#    'lat': '48.4308801',
#    'lon': '-2.5483916',
#    'display_name': "Le Havre, Landéhen, Saint-Brieuc, Côtes-d'Armor, Bretagne, France métropolitaine, 22400, France",
#    'class': 'place',
#    'type': 'isolated_dwelling',
#    'importance': 0.5}]]

# %%
len(rez)
# Out:
# 4

# %%
rez[2][0]
# Out:
# {'place_id': 298563984,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 145776,
#  'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378'],
#  'lat': '49.2764624',
#  'lon': '-0.7024738',
#  'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.7827003853621928,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}

# %%
rez[2][0]['display_name'].split(",")[0]
# Out:
# 'Bayeux'

# %%
rez[2][0]
# Out:
# {'place_id': 298563984,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 145776,
#  'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378'],
#  'lat': '49.2764624',
#  'lon': '-0.7024738',
#  'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.7827003853621928,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}

# %%
dic={'names':rez[0][0]['display_name'].split(",")[0],'lat':rez[0][0]['lat'],'lon':rez[i][0]['lon']}
df=pd.DataFrame(dic,index=[0])
df
# Out:
#                names         lat        lon
# 0  Mont Saint-Michel  48.6359541  0.1079732

# %%
for i in range(len(villes)):
  dic1={'names':rez[i][0]['display_name'].split(",")[0],'lat':rez[i][0]['lat'],'lon':rez[i][0]['lon']}
  df1=pd.DataFrame(dic1,index=[i])
  # df=df.append(df1)
  df = pd.concat([df, df1])
df
# Out:
#                names         lat                 lon
# 0  Mont Saint-Michel  48.6359541           0.1079732
# 0  Mont Saint-Michel  48.6359541  -1.511459954959514
# 1         Saint-Malo   48.649518          -2.0260409
# 2             Bayeux  49.2764624          -0.7024738
# 3           Le Havre  49.4938975           0.1079732

# %%
df2=df.iloc[1:,:]
df2
# Out:
#                names         lat                 lon
# 0  Mont Saint-Michel  48.6359541  -1.511459954959514
# 1         Saint-Malo   48.649518          -2.0260409
# 2             Bayeux  49.2764624          -0.7024738
# 3           Le Havre  49.4938975           0.1079732

# %%
df2.loc[1:,['lat']]
# Out:
#           lat
# 1   48.649518
# 2  49.2764624
# 3  49.4938975

# %%
n,m=df2.shape

# %%
rainlist=[]
windlinst=[]
for i in range(n):
  a=df2.loc[i,['lat']]
  b=df2.loc[i,['lon']]

  # print(a ,b)

  #les params
  paylods={'lat':a ,'lon':b ,'cnt':'7', 'exclude':'minutely','appid':'keyhere'}
  rweather=requests.get('https://api.openweathermap.org/data/3.0/onecall?',params=paylods)

  # print(rweather.json().keys())

  dailyinfo=pd.DataFrame(rweather.json()['daily'])
  dailyinfo=dailyinfo.loc[:,['wind_speed','rain']]
  
  # print(dailyinfo.mean())

  rainlist.append(dailyinfo['rain'].mean())
  windlinst.append(dailyinfo['wind_speed'].mean())
  lat.append(a)
  lon.append(b)

print('les villes',list(df2['names']))  
print('rain mean',rainlist)  
print('windspeed mean',windlinst)
# Out:
# les villes ['Mont Saint-Michel', 'Saint-Malo', 'Bayeux', 'Le Havre']
# rain mean [3.3475, 2.5725, 2.68625, 3.85]
# windspeed mean [6.9475, 7.76, 6.8525, 7.821250000000001]

# %%
datafinal=pd.DataFrame({'citys' : list(df2['names']) ,
                        'rain_mean' : rainlist},
                       columns=['citys','rain_mean'])
datafinal['windspeed_mean']=windlinst

# %%
df2.loc[:,['lat','lon']]
# Out:
#           lat                 lon
# 0  48.6359541  -1.511459954959514
# 1   48.649518          -2.0260409
# 2  49.2764624          -0.7024738
# 3  49.4938975           0.1079732

# %%
datafinal['lat']=df2.loc[:,['lat']]
datafinal['lon']=df2.loc[:,['lon']]

# %%
datafinal
# Out:
#                citys  rain_mean  windspeed_mean         lat  \
# 0  Mont Saint-Michel    3.34750         6.94750  48.6359541
# 1         Saint-Malo    2.57250         7.76000   48.649518
# 2             Bayeux    2.68625         6.85250  49.2764624
# 3           Le Havre    3.85000         7.82125  49.4938975
#
#                   lon
# 0  -1.511459954959514
# 1          -2.0260409
# 2          -0.7024738
# 3           0.1079732

# %% [markdown]
# # ***save it into csv ***

# %%
import os  
os.makedirs('projet kayak', exist_ok=True)  
datafinal.to_csv('projet kayak/kayak.csv')

# %%
datafinal.to_csv(index=False)
# Out:
# 'citys,rain_mean,windspeed_mean,lat,lon\nMont Saint-Michel,3.3475,6.9475,48.6359541,-1.511459954959514\nSaint-Malo,2.5725,7.76,48.649518,-2.0260409\nBayeux,2.68625,6.8525,49.2764624,-0.7024738\nLe Havre,3.85,7.821250000000001,49.4938975,0.1079732\n'

# %%
test=pd.read_csv('/content/projet kayak/kayak.csv')
test.head()
# Out:
#    Unnamed: 0              citys  rain_mean  windspeed_mean        lat  \
# 0           0  Mont Saint-Michel    3.34750         6.94750  48.635954
# 1           1         Saint-Malo    2.57250         7.76000  48.649518
# 2           2             Bayeux    2.68625         6.85250  49.276462
# 3           3           Le Havre    3.85000         7.82125  49.493898
#
#         lon
# 0 -1.511460
# 1 -2.026041
# 2 -0.702474
# 3  0.107973

# %% [markdown]
# # **to drop unamed 0**

# %%
# test.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# # ***lets rename it nd keep it for now ***

# %%
test=test.rename(columns={"Unnamed: 0": "id"})

# %% [markdown]
# # ***sort by rain nd wndspd***

# %%
sorted=test.sort_values(by=['rain_mean','windspeed_mean'],ascending=True,axis=0)
sorted
# Out:
#    id              citys  rain_mean  windspeed_mean        lat       lon
# 1   1         Saint-Malo    2.57250         7.76000  48.649518 -2.026041
# 2   2             Bayeux    2.68625         6.85250  49.276462 -0.702474
# 0   0  Mont Saint-Michel    3.34750         6.94750  48.635954 -1.511460
# 3   3           Le Havre    3.85000         7.82125  49.493898  0.107973

# %% [markdown]
# # ***plotly x***

# %%
fig = px.scatter_mapbox(sorted, lat="lat",
                        lon="lon", 
                        color="rain_mean", 
                        size="windspeed_mean", 
                        zoom=10, 
                        mapbox_style="carto-positron")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="83973e89-d402-4e8e-944b-dbc122ffbbc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83973e89-d402-4e8e-944b-dbc122ffbbc0")) {                    Plotly.newPlot(                        "83973e89-d402-4e8e-944b-dbc122ffbbc0",                        [{"hovertemplate":"windspeed_mean=%{marker.size}<br>lat=%{lat}<br>lon=%{lon}<br>rain_mean=%{marker.color}<extra></extra>","lat":[48.649518,49.2764624,48.6359541,49.4938975],"legendgroup":"","lon":[-2.0260409,-0.7024738,-1.511459954959514,0.1079732],"marker":{"color":[2.5725,2.68625,3.3475,3.85],"coloraxis":"coloraxis","size":[7.76,6.8525,6.9475,7.821250000000001],"sizemode":"area","sizeref":0.019553125},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity ...

# %%
pio.write_html(fig, "figure.html")

# %% [markdown]
# # ***api part ends here ***

# %% [markdown]
# # ***SCraping bookin***

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
# Import BeautifulSoup
from bs4 import BeautifulSoup

# Instanciate BeautifulSoup class
soup = BeautifulSoup("<html>data</html>", "html.parser") # Here we used an HTML Parser

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.2)

# %%
pip install html5lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)

# %%
url='https://www.booking.com/searchresults.fr.html?ss=paris'
response=requests.get(url,'html.parser')
soup=BeautifulSoup(response.content,'lxml')

# %%
soup.title
# Out:
# <title>
# Booking.com
# :
# Résultats de votre recherche
# .
# Réservez votre hôtel dès maintenant !
# </title>

# %%
soup.head
# Out:
# <head><script nonce="9H2PPs8dtt8LdsG" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# var optanonBoxClosedCookieName = 'OptanonAlertBoxClosed';
# var halfOfYearMillis = 180 * 24 * 60 * 60 * 1000;
# function isDefined(value) {
# return value && value !== "undefined";
# }
# function parseConsentToObject(consent) {
# var result = {};
# if (typeof consent === 'string') {
# var parts = consent.split('&');
# parts.forEach(function (part) {
# var keyAndValue = part.split('=');
# result[keyAndValue[0]] = keyAndValue[1];
# });
# }
# return result;
# }
# function isConsentValid(consent, alertBoxClosed) {
# return isDefined(consent) &&
# isDefined(alertBoxClosed) &&
# new Date() - new Date(alertBoxClosed) <= halfOfYearMillis;
# }
# function getCookie(name) {
# name += "=";
# var cookies = document.cookie.split(";");
# for (var i = 0; i < cookies.length; i += 1) {
# var cookie = cookies[i];
# while (cookie.charAt(0) === " ") {
# cookie = cookie.substring(1, cookie.length);
# }
# if (cookie.indexOf(name) === 0) {
# return cookie.substring(name.length, cookie.length);
# }
# }
# return null;
# }
# function doesGeolocationRequireBanner() {
# // In case window.PCM is not defined, fallback to opt-out
# return window.PCM ? window.PCM.isCountryNeedCookieBanner : true;
# }
# function getExplicitConsent() {
# var consent = getCookie(optanonConsentCookieName);
# var alertBoxClosed = getCookie(optanonBoxClosedCookieName);
# if (isConsentValid(consent, alertBoxClosed)) {
# var consentObject = parseConsentToObject(consent);
# return Object
# .keys(consentGroupIsAllowed)
# .map(function (purpose) {
# var result = {};
# result[purpose] = consentObject.groups.indexOf(consentGroupIsAllowed[purpose]) > -1;
# return result;
# })
# .reduce(
# function (result, currentValue) {
# return Object.assign(result, currentValue);
# }, {
# functional: true
# }
# );
# }
# }
# function getImplicitConsent() {
# var consentValue = !doesGeolocationRequireBanner();
# return {
# functional: true,
# analytical: consentValue,
# marketing: consentValue
# };
# }
# function getValue() {
# var consent = getExplicitConsent();
# if (!consent) {
# consent = getImplicitConsent();
# }
# return consent;
# }
# return {
# getValue: getValue
# };
# });
# //c360 javascript tracker first iteration
# //sends a track request to c360 http tracker
# //in order to use it:
# //1. inline the c360Tracker.js in the page you need to use it
# //2. in your js file:
# //
# // var c360Tracker = B.require('c360Tracker');
# // var event = {
# // action_name:"accommodation_checkout_confirmation_viewed",
# // action_version :"0.2.0",
# // content : { "transaction_id" : 123434},
# // user : { "BKNG_user_id": 123434}
# // };
# // c360Tracker.track(event);
# B.define('c360Tracker', function () {
# var enrichedContext = {};
# var configuration = {
# validateInput: false
# };
# var track = function (event) {
# if (event == null) {
# return "event object is null or empty";
# } else {
# //if (enrichedContext.userID != null) {
# // event.user = {BKNG_user_id: enrichedContext.userID};
# //}
# var validationResult = new ValidationResult(true);
# if (configuration.validateInput) {
# validationResult = validateInput(event);
# }
# if (!validationResult.success) {
# return validationResult.message;
# }
# send(event);
# }
# };
# function send(data) {
# data.context = enrichedContext;
# data.tracker = {
# tracker_name: "C360JSTracker",
# tracker_type: "Client",
# tracker_version: "0.1.0"
# };
# return $.ajax({
# url: '/c360/v1/track',
# type: 'POST',
# data: JSON.stringify(data),
# });
# }
# enrich();
# var scheme =
# {
# "type": "object",
# "properties": {
# "action_name": {
# "type": "string",
# "description": "action name (ex. element viewed)",
# },
# "action_version": {
# "type": "string",
# "description": "action version"
# },
# "content": {
# "type": "object",
# "description": "content defined by the registered producer scheme"
# }
# }
# };
# function ValidationResult(success, message) {
# this.success = success;
# this.message = message;
# }
# function validateInput(event) {
# var result = validateObject(event, scheme);
# return result;
# }
# function validateObject(obj, scheme) {
# if (scheme.properties != null) {
# var propsArray = Object.getOwnPropertyNames(scheme.properties);
# for (var i = 0; i < propsArray.length; i++) {
# var propertyName = propsArray[i];
# if (obj[propertyName] == null) {
# return new ValidationResult(false, "property " + propertyName + " is not defined");
# }
# if (scheme.properties[propertyName].type == "object") {
# var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
# if (validationResult.success === false) {
# return validationResult;
# }
# }
# }
# }
# return new ValidationResult(true);
# }
# function enrich() {
# enrichedContext = {
# page: {
# page_referrer: document.referrer,
# page_url: window.location.href,
# page_title: document.title
# },
# local: {
# currency: B.env.b_selected_currency
# },
# };
# //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
# // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
# }
# return {
# track: track
# };
# });
# })
# </script>
# <script nonce="9H2PPs8dtt8LdsG" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>
# <script nonce="9H2PPs8dtt8LdsG" type="text/javascript">
# (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <script nonce="9H2PPs8dtt8LdsG" type="text/javascript">
# window.PCM = {
# isCountryNeedCookieBanner: 1,
# isGpcSignalEnabled: 0,
# loadStartedAt: 1683546217,
# countryCode: 'fr',
# isUserLoggedIn: 0
# }
# </script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="9H2PPs8dtt8LdsG" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.40/customer/cookie-banner.min.js" type="text/javascript"></script>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <meta content="origin" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <script nonce="9H2PPs8dtt8LdsG">
# ;(function(w){
# var ts = +new Date();
# w.PageLoadTimer = {};
# w.PageLoadTimer.start = ts;
# }(window));
# </script>
# <script nonce="9H2PPs8dtt8LdsG"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>
# <script nonce="9H2PPs8dtt8LdsG">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>
# <script async="" class="crossorigin-check-js" crossorigin="" nonce="9H2PPs8dtt8LdsG" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>
# <script nonce="9H2PPs8dtt8LdsG">
# ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#  </script>
# <link data-main-css="1" href="https://cf.bstatic.com/static/css/main_cloudfront_sd.iq_ltr/b7bedd8993e48f83754c034aeb06b5dacff5c174.css" id="main-css-preload" rel="stylesheet"/>
# <script nonce="9H2PPs8dtt8LdsG">
# document.querySelector('#main-css-preload').addEventListener('load', function() {
# window.mainCssWasLoaded = 1;
# })
# </script>
# <link href="https://cf.bstatic.com/static/css/main_exps_cloudfront_sd.iq_ltr/4f8186113f9877f79af82b057c8bb2f85ca0894f.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/static/css/gprof_icons_cloudfront_sd.iq_ltr/45e1448a045ffbbe4ac3c464fb98c5df7c0fe7cd.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/static/css/searchresults_cloudfront_sd.iq_ltr/c723d384ddcbf4408e346a60ec8f315dea1bcb2e.css" media="screen" rel="stylesheet" type="text/css"/>
# <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/hotel_base_cloudfront_sd.iq_ltr/3d34b576293988bb2f066b0cef9b6a175571d69c.css" rel="_prefetch"/>
# <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/hotel_experiments_cloudfront_sd.iq_ltr/71cc0a87dc570faffdd23851ba28cbc3dd55b811.css" rel="_prefetch"/>
# <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/index_cloudfront_sd.iq_ltr/734b2648184ebc99f5735aad975877c414864c51.css" rel="_prefetch"/>
# <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/xp-index-sb_cloudfront_sd.iq_ltr/58c63e4d3e4eb7090033901e75e2c80c0caa437b.css" rel="_prefetch"/>
# <link href="https://cf.bstatic.com/static/css/incentives_cloudfront_sd.iq_ltr/c253238e9a1cc9e8fe7f142462ea4345a2c72799.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://cf.bstatic.com/static/css/mlt_cloudfront_sd.iq_ltr/a16f65a9f1ea4fe66f655f7dfd84da1b754a3539.css" rel="stylesheet"/>
# <style nonce="9H2PPs8dtt8LdsG"> #basiclayout, .basiclayout { margin: 0; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: auto !important; } .nobg { background: #fff url("https://cf.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png") repeat-x; background-position: 0 -50px; } </style>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/core-deps-inlinedet_cloudfront_sd/6da0bf621035bb8a2f9c756d6a89dda03b2f7864.js" nonce="9H2PPs8dtt8LdsG" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/jquery_cloudfront_sd/e1e8c0e862309cb4caf3c0d5fbea48bfb8eaad42.js" nonce="9H2PPs8dtt8LdsG" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/main_cloudfront_sd/935550a7f826e6d7030499dd9dcde65892e13a5f.js" nonce="9H2PPs8dtt8LdsG" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/searchresults_cloudfront_sd/f3dbfb922ba9aeac26773bec0b0fbf2f3a320810.js" nonce="9H2PPs8dtt8LdsG" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/0acd2ada6c74d5dec978a04ea837952bdf050cd2.js" nonce="9H2PPs8dtt8LdsG" rel="preload"/>
# <script nonce="9H2PPs8dtt8LdsG"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>
# <title>
# Booking.com
# :
# Résultats de votre recherche
# .
# Réservez votre hôtel dès maintenant !
# </title>
# <meta content="Hôtel,  Hôtels, hébergement, logement, Offres spéciales, promotions, offres week-ends, Prix compétitifs, réductions, prix bon marché" name="keywords"/>
# <meta content="noindex,follow" name="robots"/>
# <link href="https://www.booking.com/searchresults.fr.html" rel="canonical"/>
# <meta content="UmFuZG9tSVYE5ptn9Xu_hDOLWZjcn74xihk4eHy8fnydEwBIVRlFuRLKVp2liLKwIpqL9TeaPZnieltdlJ4_0I4sP3d9wDv76VuaXySsvBTGSRKBdQIQXMP7xycU8dRBFB8r_m-viLX2rLp_dSEzRB3RxSVQRFVAiTXQHdFVtzVq1-NQznoSZSDB87gbx34BUoNa2T43x1R6WfwPAhHC_n_XPN9RKkLlhCjHScVBHSCa76rVsCG2anlkGa2mt5iqsHl3JeBAJJfaRUVYlFK49rqh7hIqMxMdw0UkVB0G9I0y87fKka1Pr6ZC38U8_bSPe6oImwLfuQ0" name="booking-verification"/>
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="ff7f0b90ebb93e5bf7c7cafe77640ec1" name="p:domain_verify"/>
# <meta content="fr" http-equiv="content-language"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="_top" http-equiv="window-target"/>
# <meta content="131840030178250, 1425349334428496, 117615518393985, 1565844503706287, 517612321758712, 1668799180037291, 265097377176252, 1643712662515912, 303492549842824, 1638321783047271, 809709019119342, 959185470826086, 217466488652137, 641365839348517, 203741606405114" property="fb:pages"/>
# <meta content="48970bbca45d28c2" property="wb:webmaster"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="website" property="og:type"/>
# <meta content="À l'aide ! Quel est le meilleur hébergement ?" property="og:title"/>
# <meta content="J'ai trouvé ces super hôtels sur Booking.com et je les adore tous. Aidez-moi à faire mon choix !" property="og:description"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="https://www.booking.com/searchresults.fr.html" property="og:url"/>
# <meta content="Booking.com" property="og:site_name"/>
# <meta content="145362478954725" property="fb:app_id"/>
# <link href="https://www.booking.com/searchresults.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.de.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html"/>
# <link href="https://www.booking.com/searchresults.nl.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html"/>
# <link href="https://www.booking.com/searchresults.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html"/>
# <link href="https://www.booking.com/searchresults.es.html" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://www.booking.com/searchresults.es-ar.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.es-mx.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ca.html" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://www.booking.com/searchresults.it.html" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pt-pt.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pt-br.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.no.html" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://www.booking.com/searchresults.fi.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sv.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://www.booking.com/searchresults.da.html" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://www.booking.com/searchresults.cs.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/searchresults.hu.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ro.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/searchresults.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://www.booking.com/searchresults.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pl.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.el.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ru.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/searchresults.tr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/searchresults.bg.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ar.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/searchresults.he.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/searchresults.lv.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.uk.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/searchresults.id.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ms.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/searchresults.th.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/searchresults.et.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/searchresults.hr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.lt.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sk.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sl.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/searchresults.vi.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/searchresults.tl.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/searchresults.is.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <link href="https://cf.bstatic.com/static/img/favicon-new-32/40749a316c45e239a7149b6711ea4c48d10f8d89.ico" rel="icon" sizes="any"/>
# <link href="https://cf.bstatic.com/static/img/favicon/9ca83ba2a5a3293ff07452cb24949a5843af4592.svg" rel="icon" type="image/svg+xml"/>
# <link href="https://cf.bstatic.com/static/img/apple-touch-icon-blue/5db9fd30d96b1796883ee94be7dddce50b73bb38.png" rel="apple-touch-icon"/>
# <link href="/faq.fr.html&amp;" rel="help"/>
# <link href="https://cf.bstatic.com/static/opensearch/fr/ab4c8e0e132d315ad6fb6ddf052295ee78c91070.xml" rel="search" title="Booking.com réservations d'hôtels en ligne" type="application/opensearchdescription+xml"/>
# <link href="https://plus.google.com/105443419075154950489" rel="publisher"/>
# <script nonce="9H2PPs8dtt8LdsG">
# /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# isRetina : window.devicePixelRatio > 1,
# "b_gtt": 'dLYAeZFVJfNTBBFWZBdeFYEQIfVNHZXcbWYaYZXC',
# "b_action" : 'searchresults',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_travel_comm_url_with_lang": 'https://community.booking.com/?profile.language=fr',
# "b_calendar2" : '1',
# "BHDTJdReLGMeEcYPffcVDZBZMO": true,
# "b_max_los_data_for_prefilled_dest" : {"experiment":null,"extended_los":90,"has_extended_los":0,"is_fullon":0,"default_los":90,"max_allowed_los":90},
# /*
# */
# "b_partner_channel_id": '3',
# "b_bookings_owned": '1',
# "b_google_maps_key_params" : 'true&indexing=true',
# "b_lang" : 'fr',
# "b_has_valid_dates": 0,
# "b_countrycode" : '',
# "b_guest_country" : 'fr',
# "b_locale" : 'fr-fr',
# "b_lang_for_url" : 'fr',
# "b_this_urchin" : '/searchresults.fr.html&',
# "b_flag_to_suggest" : 'fr',
# "b_companyname" : 'Booking.com',
# "b_partner_vertical" : 'channel_direct',
# b_date_format: {"short_date_without_year":"{day_of_month} {short_month_name}","day_short_month_year_until":"jusqu'au {day_name} {short_month_name} {full_year}","day_month_year_from":"du {day_name} {month_name} {full_year}","long_date_range_both_years":"{day_of_month} {month_name} {full_year} - {day_of_month_until} {month_name_until} {full_year_until}","ux_day_month":"","date_with_weekday_time_until":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} jusqu'à {time}","day_short_month_year_other":"{day_name_other} {short_month_name} {full_year}","date_with_year":"{day_of_month} {month_name} {full_year}","date_with_weekday_time_from":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} à partir de {time}","day_month_from":"du {day_name} {month_name}","date_range_with_short_weekday_short_month":"{short_weekday} {day_of_month} {short_month_name} - {short_weekday_until} {day_of_month_until} {short_month_name_until}","from_month_with_year":"depuis {month_name_from} {full_year}","day_month_between":"entre le {day_name} {month_name} et le {day_name_until} {month_name_until}","day_month_year_other":"{day_other} {month_name} {full_year}","numeric_day_month_year":"{day_name_0}/{month_name_0}/{full_year}","date_with_short_weekday_without_year":"{short_weekday} {day_of_month} {month_name}","date_with_weekday_time_from_until":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year}, de {time} à {time_until}","short_month_with_year":"{short_month_name} {full_year}","day_short_month_time":"{day_of_month} {short_month_name}, {time}","day_short_month_year_time_between":"{day_of_month} {short_month_name} {full_year}, {time} - {time_until}","date_with_weekday_to":"{weekday_to} {day_of_month} {month_name_to} {full_year}","numeric_day_month_year_time_before":"avant le {day_name_0}/{month_name_0}/{full_year} à {time}","day_short_month_between":"{day_of_month} {short_month_name} - {day_of_month_until} {short_month_name_until}","day_short_month_year":"{day_name} {short_month_name} {full_year}","day_month_until":"jusqu'au {day_name} {month_name}","range_from_long_date_time_until_long_date_time":"du {day_of_month} {month_name} {full_year} à {time} jusqu'au {day_of_month_until} {month_name_until} {full_year_until} à {time_until}","date_with_weekday":"{weekday} {day_of_month} {month_name} {full_year}","date_with_weekday_with_markers":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year}","day_month_year_on":"le {day_name} {month_name} {full_year}","in_month_with_year":"en {month_name_in} {full_year}","numeric_day_month_year_on":"le {day_name_0}/{month_name_0}/{full_year}","day_short_month_year_time":"{day_of_month} {short_month_name} {full_year}, {time}","day_of_month_only":"{day_of_month}","short_date_without_year_range":"{day_of_month} {short_month_name} - {day_of_month_until} {short_month_name_until}","day_month_year":"{day_name} {month_name} {full_year}","numeric_date_range":"{day_of_month}/{month} - {day_of_month_until}/{month_until}","numeric_date_range_both_years":"{day_of_month}/{month}/{full_year} - {day_of_month_until}/{month_until}/{full_year_until}","day_short_month_year_from":"du {day_name} {short_month_name} {full_year}","day_month_year_time_before":"avant le {day_name} {month_name} {year} à {time}","numeric_day_month_year_from":"à partir du {day_name_0}/{month_name_0}/{full_year}","month_name_only":"{month_name_nom}","date_with_weekday_time_at":"date_with_weekday_time_at","date_with_short_weekday_with_year":"{short_weekday} {day_of_month} {month_name} {full_year}","day_month_on":"le {day_name} {month_name}","numeric_date":"{day_of_month}/{month}/{full_year}","short_weekday_only":"{short_weekday}","day_month_year_between":"entre le {day_name} {month_name} {full_year} et le {day_name_until} {month_name_until} {full_year_until}","ux_day_month_on":"le {day_2} {month_2}","day_month_other":"{day_other} {month_name}","date_without_year":"{day_of_month} {mont ...
# b_month_for_formatted_date: {"1":{"genitive_uc":"Janvier","name_def_article_uc":"Le mois de janvier","short_name_only":"Janv.","genitive_lc":"janvier","on_day_month":"01","short_name_uc":"janvier","name_to":"janvier","month_2":"janvier","day_to":"janvier","in_month_lc":"en janvier","name_lc":"janvier","name":"janvier","name_other":"janvier","month_1":"janvier","to_month_lc":"janvier","name_uc":"de janvier","name_in":"janvier","short_name":"janv.","name_only":"janvier","name_def_article_lc":"le mois de janvier","name_from":"janvier","name_with_year_only":"Janvier"},"10":{"name_def_article_uc":"Le mois d'octobre","genitive_uc":"Octobre","short_name_only":"Oct.","in_month_lc":"en octobre","name_lc":"octobre","genitive_lc":"octobre","name":"octobre","name_other":"octobre","month_1":"octobre","to_month_lc":"octobre","name_uc":"d'octobre","name_in":"octobre","on_day_month":"10","short_name":"oct.","short_name_uc":"octobre","name_only":"octobre","name_to":"octobre","name_def_article_lc":"le mois d'octobre","name_with_year_only":"Octobre","name_from":"octobre","month_2":"octobre"},"11":{"short_name_only":"Nov.","in_month_lc":"en novembre","name_def_article_uc":"Le mois de novembre","genitive_uc":"Novembre","name_lc":"novembre","name":"novembre","genitive_lc":"novembre","month_1":"novembre","to_month_lc":"novembre","name_uc":"de novembre","name_other":"novembre","on_day_month":"11","short_name":"nov.","name_in":"novembre","short_name_uc":"novembre","name_only":"novembre","name_with_year_only":"Novembre","name_from":"novembre","month_2":"novembre","name_to":"novembre","name_def_article_lc":"le mois de novembre"},"12":{"short_name_uc":"décembre","short_name":"déc.","on_day_month":"12","name_in":"décembre","month_2":"décembre","name_from":"décembre","name_with_year_only":"Décembre","name_to":"décembre","name_def_article_lc":"le mois de décembre","name_only":"décembre","name_lc":"décembre","name":"décembre","genitive_lc":"décembre","in_month_lc":"en décembre","short_name_only":"Déc.","name_def_article_uc":"Le mois de décembre","genitive_uc":"Décembre","name_uc":"de décembre","to_month_lc":"décembre","month_1":"décembre","name_other":"décembre"},"2":{"name_def_article_lc":"le mois de février","name_from":"février","name_with_year_only":"Février","name_only":"février","name_in":"février","short_name":"févr.","name_other":"février","name_uc":"de février","to_month_lc":"février","month_1":"février","name_lc":"février","name":"février","in_month_lc":"en février","day_to":"février","name_to":"février","month_2":"février","short_name_uc":"février","on_day_month":"02","genitive_lc":"février","name_def_article_uc":"Le mois de février","genitive_uc":"Février","short_name_only":"Fév."},"3":{"short_name_uc":"mars","on_day_month":"03","name_to":"mars","month_2":"mars","genitive_lc":"mars","genitive_uc":"Mars","name_def_article_uc":"Le mois de mars","short_name_only":"Mars","name_in":"mars","short_name":"mars","name_def_article_lc":"le mois de mars","name_with_year_only":"Mars","name_from":"mars","name_only":"mars","name_lc":"mars","name":"mars","in_month_lc":"en mars","day_to":"mars","name_other":"mars","to_month_lc":"mars","name_uc":"de mars","month_1":"mars"},"4":{"genitive_uc":"Avril","name_def_article_uc":"Le mois d'avril","in_month_lc":"en avril","short_name_only":"Avr.","name_lc":"avril","name":"avril","genitive_lc":"avril","name_other":"avril","to_month_lc":"avril","month_1":"avril","name_uc":"d'avril","name_in":"avril","short_name":"avr.","on_day_month":"04","short_name_uc":"avril","name_only":"avril","name_def_article_lc":"le mois d'avril","name_to":"avril","month_2":"avril","name_from":"avril","name_with_year_only":"Avril"},"5":{"name_lc":"mai","name":"mai","genitive_lc":"mai","in_month_lc":"en mai","short_name_only":"Mai","name_def_article_uc":"Le mois de mai","genitive_uc":"Mai","to_month_lc":"mai","month_1":"mai","name_uc":"de mai","name_other":"mai","short_name_uc":"mai","on_day_month":"05","short_name":"mai","name_in":"mai","month_2":"ma ...
# b_weekday_formatted_date: {"1":{"shortest":"lu","name_from_preposition":"À partir de lundi","name_lc":"lundi","name":"lundi","short":"lun.","name_uc":"Lundi","name_on":"lundi","name_other":"lundi","short_uc":"Lun.","name_from":"lundi","name_to":"lundi","name_other_uc":"lundi"},"2":{"name_other_uc":"mardi","name_to":"mardi","name_from":"mardi","short_uc":"Mar.","name_on":"mardi","name_other":"mardi","short":"mar.","name_uc":"Mardi","name":"mardi","name_lc":"mardi","name_from_preposition":"À partir de mardi","shortest":"ma"},"3":{"short":"mer.","name_uc":"Mercredi","short_uc":"Mer.","name_other":"mercredi","name_on":"mercredi","name_from":"mercredi","name_other_uc":"mercredi","name_to":"mercredi","shortest":"me","name_from_preposition":"À partir de mercredi","name_lc":"mercredi","name":"mercredi"},"4":{"name_on":"jeudi","name_other":"jeudi","short_uc":"Jeu.","name_uc":"Jeudi","short":"jeu.","name_to":"jeudi","name_other_uc":"jeudi","name_from":"jeudi","name_from_preposition":"À partir de jeudi","shortest":"je","name":"jeudi","name_lc":"jeudi"},"5":{"name_to":"vendredi","name_other_uc":"vendredi","name_from":"vendredi","name_other":"vendredi","name_on":"vendredi","short_uc":"Ven.","name_uc":"Vendredi","short":"ven.","name_lc":"vendredi","name":"vendredi","name_from_preposition":"À partir de vendredi","shortest":"ve"},"6":{"name_from_preposition":"À partir de samedi","shortest":"sa","name_lc":"samedi","name":"samedi","name_other":"samedi","name_on":"samedi","short_uc":"Sam.","name_uc":"Samedi","short":"sam.","name_to":"samedi","name_other_uc":"samedi","name_from":"samedi"},"7":{"shortest":"di","name_from_preposition":"À partir de dimanche","name":"dimanche","name_lc":"dimanche","name_uc":"Dimanche","short":"dim.","name_other":"dimanche","name_on":"dimanche","short_uc":"Dim.","name_from":"dimanche","name_to":"dimanche","name_other_uc":"dimanche"},"8":{"name_lc":"every day","name":"Tous les jours","name_other":"name_other","short_uc":"short_uc","name_uc":"name_uc","name_other_uc":"name_other_uc","name_from_preposition":"À partir de n'importe quel jour de la semaine","shortest":"shortest","name_on":"name_on","short":"short","name_to":"name_to","name_from":"name_from"}},
# b_time_format: {"AM_symbol":{"name":"AM"},"PM_symbol":{"name":"PM"},"time":{"name":"{hour_24h_no0}h{minutes}"},"time_12":{"name":"{hour_12h_no0}:{minutes} {AM_PM}"},"time_24":{"name":"{hour_24h_no0}h{minutes}"}},
# "b_protocol": 'https',
# b01: 1,
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# b_check_ot_consent : 1,
# bui: {
# color: {
# bui_color_grayscale_dark: "#333333",
# bui_color_grayscale: "#6B6B6B",
# bui_color_grayscale_light: "#BDBDBD",
# bui_color_grayscale_lighter: "#E6E6E6",
# bui_color_grayscale_lightest: "#F5F5F5",
# bui_color_primary_dark: "#00224F",
# bui_color_primary: "#003580",
# bui_color_primary_light: "#BAD4F7",
# bui_color_primary_lighter: "#EBF3FF",
# bui_color_primary_lightest: "#FAFCFF",
# bui_color_complement_dark: "#CD8900",
# bui_color_complement: "#FEBB02",
# bui_color_complement_light: "#FFE08A",
# bui_color_complement_lighter: "#FDF4D8",
# bui_color_complement_lightest: "#FEFBF0",
# bui_color_callout_dark: "#BC5B01",
# bui_color_callout: "#FF8000",
# bui_color_callout_light: "#FFC489",
# bui_color_callout_lighter: "#FFF0E0",
# bui_color_callout_lightest: "#FFF8F0",
# bui_color_destructive_dark: "#A30000",
# bui_color_destructive: "#CC0000",
# bui_color_destructive_light: "#FCB4B4",
# bui_color_destructive_lighter: "#FFEBEB",
# bui_color_destructive_lightest: "#FFF0F0",
# bui_color_constructive_dark: "#006607",
# bui_color_constructive: "#008009",
# bui_color_constructive_light: "#97E59C",
# bui_color_constructive_lighter: "#E7FDE9",
# bui_color_constructive_lightest: "#F1FEF2",
# bui_color_action: "#0071C2",
# bui_color_white: "#FFFFFF",
# bui_color_black: "#000000"
# }
# },
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "0",
# iuibb: "",
# bme: "",
# euibb: "",
# tp: "2"
# },
# b_run_map_sr_ajax: !!(window.history && window.history.pushState),
# b_destination_fullname: '',
# b_growls_close_fast: 1,
# fe_enable_login_with_phone_number: 1,
# asyncLoader: {
# async_assistant_entrypoint_css: 'https://cf.bstatic.com/static/css/assistant_entrypoint_cloudfront_sd.iq_ltr/611b70b00745fa4412a0101292fb0a1e4c97741e.css',
# async_assistant_entrypoint_js: 'https://cf.bstatic.com/static/js/assistant_entrypoint_cloudfront_sd/16a6ac79d0564ea12e63ca1c07de8d75b84bdf91.js',
# async_atlas_places_js: 'https://cf.bstatic.com/static/js/atlas_places_async_cloudfront_sd/9a9bcd998016ecc6409aa42c8605f7850a767a34.js',
# async_atlas_v2_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_cn_cloudfront_sd/a358d388c8c90d9c0407d3da288742e93c38c2a6.js',
# async_atlas_v2_non_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_non_cn_cloudfront_sd/db2ebeae76c7b51a7bc288822baac8ba5a2fba33.js',
# image_gallery_js: 'https://cf.bstatic.com/static/js/ski_lp_overview_panel_cloudfront_sd/9d8e7cfd33a37ffb15285d98f6970024f06cf36d.js',
# image_gallery_css: 'https://cf.bstatic.com/static/css/ski_lp_overview_panel_cloudfront_sd.iq_ltr/09286ad17357b015e15295d3ef2a7b66987dfecb.css',
# async_lists_js: 'https://cf.bstatic.com/static/js/async_lists_cloudfront_sd/07f3a4a47ebd55362a0956eabdd43231659810cb.js',
# async_atlas_css: 'https://cf.bstatic.com/static/css/async_atlas_sr_cloudfront_sd.iq_ltr/de3dab4517d52756830a07680fbf2836c4439ee8.css',
# async_sr_atlas_map_js: 'https://cf.bstatic.com/static/js/async_sr_atlas_map_cloudfront_sd/e07a51865e4e7766488652a809ba0f07b0825be1.js',
# async_ski_interactive_map: 'https://cf.bstatic.com/static/js/async_ski_interactive_map_cloudfront_sd/784be0ecd893861fab8e73cb5e722378f0c61ef3.js',
# async_nouislider_css: 'https://cf.bstatic.com/mobile/css/async_nouislider_cloudfront_sd.iq_ltr/2a32b1f38119063da104b43614194fe70d377a05.css',
# async_nouislider_js: 'https://cf.bstatic.com/mobile/js/async_nouislider_cloudfront_sd/65e580457b504e99b5475ed3093317626870204b.js',
# async_wpm_overlay_css: 'https://cf.bstatic.com/static/css/async_wpm_overlay_assets_cloudfront_sd.iq_ltr/abb304bf3600a5cf5f7406a27f042cf1ce2429b1.css',
# async_wpm_overlay_js: 'https://cf.bstatic.com/static/js/async_wpm_overlay_assets_cloudfront_sd/c6cb9b63eea61102d4e96fe72b7c8008652fe925.js',
# async_slider_view_js: 'https://cf.bstatic.com/mobile/js/async_slider_view_cloudfront_sd/b99d37dd0f12a56f66e827b1f34dbf846a345b1f.js',
# async_slider_view_css: 'https://cf.bstatic.com/mobile/css/async_slider_view_cloudfront_sd.iq_ltr/6139b93e39f06ca17bf572c4b68667c465df625d.css',
# async_beach_team_pilot_js: 'https://cf.bstatic.com/mobile/js/async_beach_team_pilot_cloudfront_sd/4ad475e13980eaf3a159e590a2c3885e1c6a1723.js',
# async_beach_team_pilot_css: 'https://cf.bstatic.com/mobile/css/async_beach_team_pilot_cloudfront_sd.iq_ltr/78a0cd85140375ef67419e51c727d5b207ce48d0.css',
# empty: ''
# },
# fe_enable_fps_goal_with_value: 1,
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'https:&#47;&#47;www.booking.com&#47;searchresults.fr.html',
# b_this_url : '/searchresults.fr.html',
# b_this_url_without_lang : '/searchresults.html',
# b_referrer : '',
# b_acc_type : '',
# b_req_login: '',
# jst : {'loading': true},
# keep_day_month: true,
# b_timestamp : 1683546217,
# scripts_tracking : {
# atlas:{loaded:false,run:false},
# atlas_cst:{loaded:false,run:false},
# bhc:{loaded:false,run:false},
# calendar2:{loaded:false,run:false},
# jquery:{loaded:false,run:false},
# main:{loaded:false,run:false},
# searchresults:{loaded:false,run:false}
# },
# enable_scripts_tracking : 1,
# b_ufi : '',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : 'Fermer',
# transl_checkin_title: 'Du ',
# transl_checkout_title: 'Au ',
# browser_lang: '',
# b_hijri_calendar_available: false,
# b_aid: '304142',
# b_label: 'gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB',
# b_sid: '90149fe82aa24bb5d2c55072c9ce38f7',
# ip_country: 'fr',
# country_currency: 'EUR',
# b_selected_currency: 'EUR',
# b_selected_currency_is_hotel_currency: "",
# b_selected_language: 'fr',
# b_selected_language_country_flag: 'fr',
# b_filter_currency: '',
# b_has_filters: 0,
# inline_sort_headers: {
# 'star_track': {
# sortHeader: 'Trier tous les établissements par étoiles'
# },
# 'big_review_score_detailed': {
# sortHeader: 'Trier tous les établissements par note des commentaires'
# },
# 'address_text': {
# sortHeader: 'Trier tous les établissements par sites à proximité'
# },
# 'district_link': {
# sortHeader: 'Trier tous les établissements par sites à proximité'
# },
# 'smart_price_style': {
# sortHeader: 'Trier tous les établissements par tarif'
# }
# },
# b_search_config: {},
# pageview_id: 'd71a5274a4900064',
# aid: '304142',
# b_csrf_token: 'qRhZZAAAAAA=r1FYFkfDxFFUrRhSEOdBTQy_BJgB3QoSEyRHEI-9kfN90mf4rxD3-mVy0MsqCGUXcRtwO0HK_6c1pmynLwsib1qPjMlZv1AT-RfvW-z-1CpRt_-dQv4pbrPhReSEcvXFf7Svgvtt6FsRMkcWVzCBkjxnUNGQClMLrwe16qQjOeyYsCxDbSte0bcHlIOlV9myS-SSNE7ww-WJ-nkr',
# b_show_user_accounts_features: 1,
# b_browser: 'bot',
# et_debug_level: '0',
# icons: '/static/img',
# b_static_images: 'https://cf.bstatic.com/images/',
# b_currency_url: '/general.fr.html&amp;tmpl=currency_foldout&amp;cur_currency=EUR',
# b_currency_change_base_url: '/searchresults.fr.html',
# b_languages_url: '/general.fr.html&amp;tmpl=language_foldout',
# b_weekdays: [
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('1'),
# "name": 'lundi',
# "short": 'lun.',
# "shorter": 'lun.',
# "shortest": 'lu'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('2'),
# "name": 'mardi',
# "short": 'mar.',
# "shorter": 'mar.',
# "shortest": 'ma'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('3'),
# "name": 'mercredi',
# "short": 'mer.',
# "shorter": 'mer.',
# "shortest": 'me'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('4'),
# "name": 'jeudi',
# "short": 'jeu.',
# "shorter": 'jeu.',
# "shortest": 'je'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('5'),
# "name": 'vendredi',
# "short": 'ven.',
# "shorter": 'ven.',
# "shortest": 've'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('6'),
# "name": 'samedi',
# "short": 'sam.',
# "shorter": 'sam.',
# "shortest": 'sa'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('7'),
# "name": 'dimanche',
# "short": 'dim.',
# "shorter": 'dim.',
# "shortest": 'di'},
# {}],
# b_group: [],
# b_simple_weekdays: ['lu','ma','me','je','ve','sa','di'],
# b_simple_weekdays_for_js: ['lun.','mar.','mer.','jeu.','ven.','sam.','dim.'],
# b_long_weekdays: ['lundi','mardi','mercredi','jeudi','vendredi','samedi','dimanche'],
# b_short_months: ['janvier','février','mars','avril','mai','juin','juillet','août','septembre','octobre','novembre','décembre'],
# b_short_months_abbr: ['janv.','févr.','mars','avr.','mai','juin','juill.','août','sept.','oct.','nov.','déc.'],
# b_year_months: {
# '2023-5': {'name': 'Mai 2023' },
# '2023-6': {'name': 'Juin 2023' },
# '2023-7': {'name': 'Juillet 2023' },
# '2023-8': {'name': 'Août 2023' },
# '2023-9': {'name': 'Septembre 2023' },
# '2023-10': {'name': 'Octobre 2023' },
# '2023-11': {'name': 'Novembre 2023' },
# '2023-12': {'name': 'Décembre 2023' },
# '2024-1': {'name': 'Janvier 2024' },
# '2024-2': {'name': 'Février 2024' },
# '2024-3': {'name': 'Mars 2024' },
# '2024-4': {'name': 'Avril 2024' },
# '2024-5': {'name': 'Mai 2024' },
# '2024-6': {'name': 'Juin 2024' },
# '2024-7': {'name': 'Juillet 2024' },
# '2024-8': {'name': 'Août 2024' }
# },
# b_user_is_new: 1,
# b_is_landing : 1,
# b_user_auth_level_is_none: 1,
# b_is_fb_safe: 1,
# b_is_app: 1,
# first_page_of_results: true,
# b_partner_id: '1',
# b_is_destination_finder_supported: 0,
# b_is_dsf: 0,
# b_pr_param: '',
# /*
# */
# feature_profile_split_sb_checkbox: 1,
# usp_overlay: [{
# title: "R\u00e9servez maintenant et payez pendant votre s\u00e9jour\u00a0!",
# body: "Annulation GRATUITE sur la majorit\u00e9 des chambres"
# },{
# title: "La r\u00e9servation est s\u00e9curis\u00e9e",
# body: "Pour chaque r\u00e9servation effectu\u00e9e sur notre site, vos donn\u00e9es personnelles sont prot\u00e9g\u00e9es par une connexion s\u00e9curis\u00e9e."
# },{
# title: "Commentaires authentiques",
# body: "259\u00a0540\u00a0000 commentaires clients authentiques"
# },
# ],
# usp_sr_load_budget_title: "Acc\u00e9dez \u00e0 des tarifs plus bas",
# usp_sr_load_budget_body: "Connectez-vous et recherchez nos Offres Privil\u00e8ge",
# inandaround_more: "Plus",
# b_signup_iframe_url: 'https://secure.booking.com' + '/login.html?tmpl=profile/signup_after_subscribe' + '&lang=fr' ,
# b_exclude_lang_firstname: 0,
# enter_dates_to_see_prices: 'Pour voir les tarifs exacts des chambres à vos dates de séjour et permettre un classement par tarif, veuillez saisir vos dates d\'arrivée et de départ dans la fenêtre de recherche sur la gauche.',
# b_available_hotels: 0,
# view_prices_enter_dates: 'Veuillez saisir vos dates pour voir les tarifs et les disponibilités.',
# b_total_selected_filters: "",
# b_current_page_nr: 1,
# b_order : "",
# autocomplete_categories: {
# city: 'Villes',
# region: 'Régions',
# airport: 'Aéroports',
# hotel: 'Hôtels',
# landmark: 'Sites d\'intérêt',
# country: 'Pays',
# district: 'Quartiers',
# theme: 'Thèmes'
# },
# autocomplete_skip_suggestions: 'Rechercher plus d\'options',
# autocomplete_counter_label: 'Établissements à proximité',
# autocomplete : {
# property_nearby: '1 établissement à proximité',
# properties_nearby: ' établissements à proximité',
# hotel: 'établissement',
# hotels: 'établissements',
# hotels_nearby: 'Établissements à proximité'
# },
# lists: {
# collection: [
# {
# id: "0",
# name: "Mon prochain voyage",
# hotels_count: "0"
# }
# ]
# },
# touch_os: false,
# calendar_days_allowed_number: 358,
# b_search_max_months: 16,
# b_run_ge_new_newsletter_login: 1,
# b_password_strength_msg: ['Pas assez de caractères','Faible','Correct','Bon','Fort','Très fort'],
# b_passwd_min_length_error: 'Votre mot de passe doit comporter au moins 8 caractères',
# b_password_must_be_numeric: 'Le code confidentiel de votre réservation doit contenir 4 chiffres. Veuillez réessayer.',
# b_bkng_nr_must_be_numeric: 'Votre numéro de réservation doit contenir 9 chiffres. Veuillez réessayer.',
# b_blank_numeric_pin: 'Veuillez saisir votre code confidentiel.',
# b_blank_bkng_nr: 'Veuillez saisir votre numéro de réservation.',
# password_cant_be_username: 'Votre adresse e-mail et votre mot de passe ne peuvent être identiques',
# b_show_passwd: 'Voir le mot de passe',
# b_passwd_tooltip: 'Insérez des majuscules, des caractères spéciaux et des chiffres pour augmenter le niveau de sécurité de votre mot de passe',
# account_error_add_password: 'Veuillez entrer votre mot de passe',
# password_needs_8: 'Votre mot de passe doit comporter au moins 8 caractères',
# error_sign_up_password_email_combo_01: 'Votre adresse e-mail ou votre mot de passe est incorrect, veuillez recommencer.',
# social_plugins_footer: 1,
# b_lazy_load_print_css: 1,
# print_css_href: 'https://cf.bstatic.com/static/css/print/0cc4ce4b7108d42a9f293fc9b654f749d84ba4eb.css',
# 'component/dropdown-onload-shower/header_signin_prompt' : {
# b_action: "searchresults"
# },
# b_hostname_signup: "www.booking.com",
# b_nonsecure_hostname: "https://www.booking.com",
# b_nonsecure_hostname_signup: "https://www.booking.com",
# b_fd_searchresults_url_signup: "",
# translation_customer_service_which_booking_no_specific: 'Pas de réservation spécifique',
# stored_past_and_upcoming_bookings: [
# ],
# global_translation_tags: {"lrm":"\u200e","line_break":"\u003cbr\u003e","zwsp":"\u200b","one_dot_leader":"\u2024","rlm":"\u200f","nbsp":"&nbsp;"},
# b_rackrates_monitoring_running: true,
# b_wishlist_referrer : '',
# b_reg_user_last_used_wishlist: "",
# b_reg_user_wishlist_remaining: 1,
# is_user_center_bar: 1,
# b_site_experiment_user_center_bar: 1,
# b_reg_user_is_genius : "",
# profile_menu: {
# b_user_auth_level: 0,
# b_domain_for_app: "https://www.booking.com",
# b_query_params_with_lang_no_ext: "",
# b_travel_comm_url_with_lang: "https://community.booking.com/?profile.language=fr",
# b_action: "searchresults",
# b_site_info: {"is_bookings_owned":1,"is_iam_auth_allowed":1},
# b_site_type: "www",
# b_companyname: "Booking.com",
# b_reg_user_full_name: "",
# b_is_genius_branded: "0",
# b_reg_user_is_genius: "",
# b_genius_dashboard_expiry_destfinder_url: "https://www.booking.com/destinationfinderdeals.fr.html;genius_deals_mode=1&genius_next_weekend=1",
# b_reg_user_last_used_wishlist: "",
# b_genius_product_page_url: "https://www.booking.com/genius.fr.html",
# b_reg_user_five_bookings_challenge: "",
# b_reg_user_detail_name_email_hash: "",
# b_user_is_grap_eligible: "",
# b_grap_remove_raf_checks: 1,
# b_is_bbtool_admin: "",
# b_is_bbtool_user: "",
# fe_bbtool_permission_is_connected_to_bbtool: "",
# fe_this_url_travel_purpose_business: "https://secure.booking.com/company/search.fr.html",
# fe_this_url_travel_purpose_leisure: "https://www.booking.com/index.fr.html",
# fe_reservations_url_travel_purpose_business: "https://secure.booking.com/company/reservations.fr.html",
# fe_reservations_url_travel_purpose_leisure: "https://secure.booking.com/myreservations.fr.html",
# fe_my_settings_url: "https://account.booking.com/oauth2/authorize?aid=304142;client_id=d1cDdLj40ACItEtxJLTo;redirect_uri=https%3A%2F%2Faccount.booking.com%2Fsettings%2Foauth_callback;response_type=code;state=Ulg16SQ7SuW4OLqQlJolROlFgSx6WWQ9Bay-NTB6JFWLz4c83t2PfKMtX0Dt2JbW1iqD4hIdbqOhiTxKXSYTmKTbZWS2sXsD2XRjUvroekzoaP8P2T0n9urg",
# fe_my_settings_url_travel_purpose_business: "https://secure.booking.com/mysettings.fr.html",
# fe_my_settings_url_travel_purpose_leisure: "https://secure.booking.com/mysettings.fr.html",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_blackout_user_company: "",
# fe_bbtool_redirect_personal_to_index: 1,
# b_reg_user_company_name: "",
# b_reg_user_company_name_escaped: "",
# b_reg_user_companyjoin_url: "",
# b_bbtool_product_page_url: "https://www.booking.com/business.fr.html",
# b_is_ie7: "",
# b_this_url: "/searchresults.fr.html",
# b_lang_for_url: "fr",
# b_secure_hostname: "https://secure.booking.com",
# b_nonsecure_hostname: "https://www.booking.com",
# b_query_params_with_lang: ".fr.html",
# b_query_params_with_lang_no_ext: "",
# b_travel_comm_url_with_lang: "https://community.booking.com/?profile.language=fr",
# b_query_params_delimiter: "&",
# b_reg_user_detail_dashboard_url: "",
# b_is_reg_user_city_guide_in_lang_available: "0",
# b_aspiring_user_fifth_booking_ufi : "",
# b_reg_user_aspiring_data: "",
# b_dummy_var_for_trailing_comma: false,
# b_ip_country: "",
# b_guest_country: "fr",
# b_agent_is_no_robot: "",
# b_page_name : "searchresults",
# b_landingpage_theme_type: "",
# b_brewards_account_details: "",
# b_upcoming_rewards: "",
# b_rewards_reminder_is_on: 1,
# fe_rewards__game_over: "1",
# loyalty_program_rules: "",
# loyalty_program_status: "",
# loyalty_program_bonus_url: "",
# b_brewards_loyalty_program_account_type: "",
# b_user_has_mobile_app: "",
# b_aid: 304142,
# b_label: "gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB",
# fe_show_travel_communities_menu_item: 1,
# fe_user_can_see_company_reservations: null,
# b_oauth_client_id: "vO1Kblk7xX9tUn2cpZLS",
# b_sso_logout_url: "",
# b_sso_logout_callback_url: "",
# fe_sso_logout_state: "",
# fe_blackout_mydashboard: "",
# fe_user_menu_aspiring_genius_link: false
# },
# accounting_config: {"html_symbol":{"EUR":"&#x20AC;","ARS":"AR$","CLP":"CL$","JPY":"&#165;","PHP":"&#8369;","HKD":"HK$","PLN":"z&#x0142;","XPF":"CFP","INR":"Rs.","RON":"lei","ILS":"&#x20AA;","USD":"US$","CZK":"K&#269;","BRL":"R$","GBP":"&#163;","IDR":"Rp","SGD":"S$","TRY":"TL"},"group_separator":{"default":" "},"symbol_position":{"PLN":"after","CZK":"after","default":"before","RON":"after"},"decimal_separator":{"default":","},"num_decimals":{"IDR":"0","VUV":"0","LAK":"0","KRW":"0","BIF":"0","MZM":"0","VND":"0","ECS":"0","PYG":"0","MGA":"0","XOF":"0","TJR":"0","JPY":"0","BYR":"0","AFA":"0","TND":"3","KMF":"0","XAF":"0","OMR":"3","KWD":"3","TWD":"0","default":"2","ISK":"0","HUF":"0","LYD":"3","RWF":"0","XPF":"0","IQD":"3","JOD":"3","UGX":"0","TMM":"0","RUB":"0","COP":"0","CLP":"0","GNF":"0","BHD":"3","DJF":"0"},"currency_separator":{"USD":"","JPY":"","default":"&nbsp;","GBP":""}},
# distance_config: "metric",
# is_listview_page: true,
# b_this_weekend_checkin: "",
# b_this_weekend_checkout: "",
# b_next_weekend_checkin: "",
# b_next_weekend_checkout: "",
# b_official_continent: "",
# b_deals_continents : "",
# tpi_sr_squeaks: {
# price_display_us: [
# [
# 'cCcCcCFBaILQLbcZTTEZYUbBaPPYEIUVNKe',
# 'cCcCcCFBaILQLbcZTTEZYUbBbMeeBXO',
# 'cCcCcCFBaILQLbcZTTEZYUbBaHAYfcC'
# ],
# [
# 'cCcCcCFBaILQLbcZTTEZYUbfaPPYEIUVNKe',
# 'cCcCcCFBaILQLbcZTTEZYUbfbMeeBXO',
# 'cCcCcCFBaILQLbcZTTEZYUbfaHAYfcC'
# ]
# ]
# },
# fe_feature_running_TPI_TEST_SR_PP_GLOBAL_SWITCH: 1,
# b_messenger_url: '',
# b_open_messenger: false,
# b_is_asian_user: '',
# b_days_to_checkin: '',
# b_extra_ajax_headers: {},
# et_debug_level: '0',
# notification_squeaks: {
# },
# wl_squeak: {
# open_wishlist_from_sr: 'ZQafLebbMTSWYO',
# create_wishlist_from_sr: 'bYDXYFdKMDNdEPUUORe',
# },
# genius_vip_squeaks: {
# gnsSpun_bannerView_sr: 'TDXRPCTOYESVCMIWIOQHFRYTKe',
# gnsSpun_bannerCtaClick_sr: 'TDXRPCTOYESVCMIWIAHIcaWGNPZSCHT',
# gnsSpun_bannerDismiss_sr: 'TDXRPCTOYESVCMIJeBObVIScORe',
# gnsSpun_modalView_sr: 'TDXRPCTOYESEIEYXWCcYbaBORe',
# gnsSpun_modalCtaClick_sr: 'TDXRPCTOYESEIEYXWIYKdVaQBYNZWYO',
# gnsInsCrd_bannerView_sr: 'TDXRPVRBKKJVbFPbVCMIWIOQHFRYTKe',
# gnsInsCrd_bannerCtaClick_sr: 'TDXRPVRBKKJVbFPbVCMIWIAHIcaWGNPZSCHT',
# gnsInsCrd_bannerDismiss_sr: 'TDXRPVRBKKJVbFPbVCMIJeBObVIScORe',
# gnsInsCrd_modalView_sr: 'TDXRPVRBKKJVbFPbEIEYXWCcYbaBORe',
# gnsInsCrd_modalCtaClick_sr: 'TDXRPVRBKKJVbFPbEIEYXWIYKdVaQBYNZWYO',
# gnsBkun_bannerView_sr: 'TDXRPVReBZAPXPRLaWNBALOCHT',
# gnsBkun_bannerCtaClick_sr: 'TDXRPVReBZAPXPRLaWBXFJVGSBBNHUC',
# gnsBkun_bannerDismiss_sr: 'TDXRPVReBZAPXPRLSZWcPXQUWYO',
# gnsBkun_modalView_sr: 'TDXRPVReBZAZXDOXVaUSIcCWYO',
# gnsBkun_modalCtaClick_sr: 'TDXRPVReBZAZXDOXVaSXbfIAbSOBYTKe',
# gnsInsDisc_bannerView_sr: 'TDXRPVRBKKQUYBFLLREHGVaUSIcCWYO',
# gnsInsDisc_bannerCtaClick_sr: 'TDXRPVRBKKQUYBFLLREHGVaSXbfIAbSOBYTKe',
# gnsInsDisc_bannerDismiss_sr: 'TDXRPVRBKKQUYBFLLREHGbNHNERGeaUC',
# gnsc_banner_view_from_sr: 'TDXRcJJKDKGbADNYTKe',
# gnsc_banner_cta_click_from_sr: 'TDXRcJJKDKGdBfdJTSWYO',
# gnsc_banner_dismiss_from_sr: 'TDXRcJJKDKGAYRGefUUORe',
# gnsi_banner_view_from_sr: 'TDXReAJKDKGbADNYTKe',
# gnsi_banner_cta_click_from_sr: 'TDXReAJKDKGdBfdJTSWYO',
# gnsi_banner_dismiss_from_sr: 'TDXReAJKDKGAYRGefUUORe',
# gnsOnbe_modalView_sr: 'TDXRPCTDfELZXDOXVaUSIcCWYO',
# gnsOnbe_modalCtaClick_sr: 'TDXRPCTDfELZXDOXVaSXbfIAbSOBYTKe',
# },
# map_open_sr_hp_squeaks: {
# mapOpenInSearchResultsOrHotelPage: 'YdXfTQdcLDWNXFBYT',
# },
# trip_types_squeaks : {
# ski_sr_d_map_no_lift_markers:'cJaUWbTQCMVCDODXPdRe',
# beach_sr_d_map_no_beach_markers:'YWYHaUWbTQCMYWYHfREFHT',
# beach_sr_d_map_no_beaches_nearby:'YWYHaUWbTQCMYWYHAbASKFWe',
# beach_sr_d_panel_response_error:'YWYHaUWbIXcYQFNSebRaTMDLfOFHe',
# beach_sr_d_async_scripts_failed:'YWYHaUWbCFeZIJDeJYQTfPIEaFXPGO',
# ski_sr_d_panel_response_error:'cJaUWbIXcYQFNSebRaTMDLfOFHe',
# dummyvar:false
# },
# insurance_squeaks : {
# mfe_ready: 'fFaMLVBGVPLXNWSLT',
# quote_reference_received: 'fFaMLAeUVKZMRKIOfFRJXZMHbAae',
# insurance_received: 'fFaMLVDERdafXdDEAJLT'
# },
# trackExperiment : function () {},
# "error" : {}
# },
# ensureNamespaceExists: function (namespaceString) {
# if (!booking[namespaceString]) {
# booking[namespaceString] = {};
# }
# }, hotel: {}, experiments: {}, startup: {}, experiments_load: {}, startup_load: {}, promotions: {}, timestamp: new Date()};
# function Tip() {};
# (function (scope) {
# booking.env.b_sb_autocomplete_predictions_url = '/autocomplete_csrf';
# booking.env.b_sb_autocomplete_predictions_method = 'GET';
# booking.env.b_sb_googleplaces_carrier_url = 'https://carrier.booking.com/google/places/webautocompletesimple';
# booking.env.b_sb_googleplaces_carrier_method = 'POST';
# var params = scope.search_autocomplete_params = {};
# params.v = '1';
# params.lang = 'fr';
# params.sid = '90149fe82aa24bb5d2c55072c9ce38f7';
# params.aid = '304142';
# params.pid = 'd71a5274a4900064';
# params.stype = '1';
# params.src = 'searchresults';
# params.eb = '0';
# params.e_obj_labels = '1';
# params.e_tclm = 1;
# params.add_themes = '1';
# params.themes_match_start = '1';
# params.include_synonyms = '1';
# }(window.autocomplete_vars || booking.env));
# </script>
# <script nonce="9H2PPs8dtt8LdsG">var _gaq = _gaq || [];</script>
# <!--[if IE]> <script nonce="9H2PPs8dtt8LdsG"> document.createElement('time'); </script> <![endif]-->
# <script nonce="9H2PPs8dtt8LdsG">
# booking.jset = {"m":"UmFuZG9tSVYkc2RlIyh9YcLMCtaNybOL3tNSVrYJwFWq5gwPthim3IfGhAIDkywv_Yh2EcTF94yLFOPywwdF3mdpE0yNSdIXC9EnQZYRUer0QMnjCrfqRsrUQMHrYbfZfStTUsIvG4pVq3d3ScOfzxMnwX0EWIofJalKosTiCNcUQnnd9ye_8nQNfIFhNoVyfaeG3dTZ829au1tWv18PFgtq6hc5k6tCeQNzkmvxuDlRCuzBtkrUqSRVcvOOAhXwFm4l7YstspI1Bd73eG2wRNagSoho9EWz","t":{"HMeVKJeGMXNZQMeYJNNQeHT":1,"YdXfdKNKNKZNTfVfdLaAFZKXe":1,"YdXfdKNKNKHUFKYOeeTQIPPSfDcdEWe":1,"BHDTJdReQHUYPUAdQMWXZSPDECBKe":1,"NVNZYeJBBYZUeQKBBTZMcET":1,"dLcXJeITPMObVcKYO":1,"YdXfMPXYZaTaTaBEUcKBSMFeJHUWEYcZbMKJZKe":9,"TZUfdbYfTLBbPTPdKNKNKHUC":1,"BHDTJdReLLCBLZBeMbFMOFIbeDUHYK
# var jst = {"dLYHMRFeRQcDaIPaMNfQCcbNXGDJae":1,"YdXfMPXYZaTaTaBEUcKBSMFeJHUWEYcZbMKJZKe":0,"TZUfdKNKNKHbCZIVFTZYBbPTHO":0,"BKATYDORMTfFIdOccPDXKe":0,"BKATYDORMTfFIdOccPDXafBQEQSVWe":0,"aDMWRfDSdWUUHfLebbMPAFFLKZLXJOfAdIUFZZcO":1,"TZUfdbYfTLBbPTPdKNKNKWe":1,"BHDTJdReLGMeEcYPffcVDZBZMO":1,"YdXfdKNKNKZNTfVfdLaAFZKXe":0,"YdXfdKNKNKHUFKYOeeTQIPPSfDcdEWe":0,"aXbSbcBUYWYHaRMSAdRTUcCcCcCC":0,"YdXfdKNKNKZUTPTQTUMKPREFcEBYJO":0,"aXbSbcOQPCPRWXdBGZXeNLOLOLMO":2,"BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe":1,"aaTBNZZJRLESPIDNJDPVBC":0,"BKATYDORMTfFIdOccPDXafBQEQJET":0};
# var jsdt = {"TZUfdbYfTLBbPTPdKNKNKWe":1,"aXbSbcOQPCPRWXdBGZXeNLOLOLMO":2,"aDMWRfDSdWUUHfLebbMPAFFLKZLXJOfAdIUFZZcO":1,"BHDTJdReLGMeEcYPffcVDZBZMO":1,"BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe":1,"dLYHMRFeRQcDaIPaMNfQCcbNXGDJae":1};
# booking.jst = jst;
# booking.jsdt = jsdt;
# booking.env.b_fragment_url_html = "/fragment.fr.html";
# booking.env.b_fragment_url_json = "/fragment.fr.json";
# booking.ensureNamespaceExists('affiliate');
# booking.affiliate.platform = {
# isHybrid: 0,
# isCobrand: 0
# };
# booking.affiliate.settings = {
# showSignUpPrompt: 0
# };
# booking.affiliate.variables = {
# userLoggedIn: 0
# };
# booking.affiliate.params = {
# destinationFinderSignUpPrompt: 0
# };
# </script>
# <script nonce="9H2PPs8dtt8LdsG">
# (function(){
# document.addEventListener('DOMContentLoaded', function(e) {
# window._pxAppId = 'PXikKuL2RM';
# setTimeout(function() {
# var pxs = document.createElement('script');
# pxs.crossOrigin = 'anonymous';
# pxs.nonce = '9H2PPs8dtt8LdsG';
# pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
# document.head.appendChild(pxs);
# }, 750);
# });
# }());
# </script>
# <script nonce="9H2PPs8dtt8LdsG" type="text/javascript">
# window.cspViolationsCount = 0;
# if ('SecurityPolicyViolationEvent' in window) {
# document.addEventListener("securitypolicyviolation", (e) => {
# if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
# window.cspViolationsCount++;
# } else if (e.disposition === 'enforce') {
# window.cspViolationsCount++;
# }
# });
# }
# </script>
# <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.5bbceacb.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-BreadCrumbsDesktop-BreadCrumbsDesktop" href="https://cf.bstatic.com/psb/capla/static/css/3735.04c268bf.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-HeaderDesktop-HeaderDesktop" href="https://cf.bstatic.com/psb/capla/static/css/9551.a30733e8.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-LeftColumnDesktop-LeftColumnDesktop" href="https://cf.bstatic.com/psb/capla/static/css/1099.202a6ed6.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-PropertiesListDesktop-PropertiesListDesktop" href="https://cf.bstatic.com/psb/capla/static/css/3569.6a73d325.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-SearchBoxDesktop-SearchBoxDesktop" href="https://cf.bstatic.com/psb/capla/static/css/4176.8e26e706.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="src-components-TripTypeRecommendations-TripTypeRecommendations" href="https://cf.bstatic.com/psb/capla/static/css/829.58104958.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="SortersDropdown-SortersDropdown" href="https://cf.bstatic.com/psb/capla/static/css/4954.7fe58ad4.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-AccommodationHeader-SearchResultHeader" href="https://cf.bstatic.com/psb/capla/static/css/1238.ef0c5ad6.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-GlobalAlerts" href="https://cf.bstatic.com/psb/capla/static/css/3665.db7fb8e8.chunk.css" nonce="9H2PPs8dtt8LdsG" rel="stylesheet"/>
# </head>

# %%
# Find the first <a> tag within HTML_DOC
link = soup.div
link
# Out:
# <div style="display:none;">Gog_sr_cc_less</div>

# %%
list(link.parents)
# Out:
# [<body class="bookings2 b2 searchresults fr lang_is_ltr header_reshuffle no_bg_img nobg user_center app_user_center sb_gradient_border b-sprite-3 ds-traveller-header lx_cwv_font_swap bigblue_std_sm bigblue_std_lg iconfont_is_loading system-font iq-x-bar iq-x-bar-new" data-bui-theme="legacy-light" id="b2searchresultsPage">
#  <div style="display:none;">Gog_sr_cc_less</div>
#  <a class="a11y-skip-to-content" href="#basiclayout">Accéder au contenu principal</a>
#  <script nonce="9H2PPs8dtt8LdsG" type="text/javascript">
#  window.utag_data = {
#  site: 'bookings2',
#  stypeid: '1',
#  action: 'searchresults',
#  crt: '1',
#  fbp: '1',
#  exp1: '',
#  exp2: '0',
#  bem: '0',
#  bip: '0',
#  exp_rmkt_test: 'global_on',
#  exp_google_tag_manager: '1',
#  ns: '1',
#  nsc: '0',
#  famem: '-1',
#  famfn: '-1',
#  fampn: '-1',
#  gcem: '-1',
#  gcpn: '-1',
#  gwcur: '-1',
#  gwcuc: '-1',
#  rb: '1',
#  gst: '1',
#  fbqs: '',
#  sage: '0',
#  alev: '0',
#  atid: '',
#  atnm: '',
#  biz_s: '2',
#  biz_p: '',
#  bo: '1',
#  browser: 'bot',
#  browser_ver: '0',
#  bstage: '',
#  emksho: '1',
#  is_subscribed_to_newsletter: '',
#  genis: '',
#  glev: '',
#  n_b: '',
#  sid: '90149fe82aa24bb5d2c55072c9ce38f7',
#  ui: '',
#  is_aid_mcc_level_tracked: '',
#  partner_channel_id: '3',
#  ttv: '',
#  ttv_uc: '',
#  p1: '0',
#  preferred_neighborhoods: [],
#  hotel_name: '',
#  channel_id: '3',
#  partner_id: '1',
#  ai: '304142',
#  tsmp: '1683546217',
#  adults: '-1',
#  book_window: '',
#  children: '-1',
#  district_name: '-1',
#  city_name: '-1',
#  region_name: '-1',
#  country_name: '-1',
#  currency: 'EUR',
#  date_in: '-1',
#  cul: '0',
#  mnns: '0',
#  date_out: '-1',
#  dayofwk: '-1',
#  depth: '1',
#  dest_type: '-1',
#  dest_id: '-1',
#  dest_cc: '',
#  dest_ufi: '-1',
#  dest_name: '',
#  hotel_count: '0',
#  hotel_id: '0',
#  hotel_id_list: '',
#  hr: '-1',
#  i1: '',
#  i2: '',
#  i3: '',
#  isfd: '',
#  isnl: '',
#  label: 'gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB',
#  language: 'fr',
#  logged_in: '0',
#  nights: '-1',
#  cv: '-1',
#  ordv: '-1',
#  rooms: '-1',
#  seed: 'jj5rI3DhNBdXjfsrd8H-PA',
#  sid_dyna: '006458e069517ac63e217bf5539222a743_1683545400',
#  srord: '-1',
#  sub: '0',
#  ui_a: '-1',
#  user_location: 'fr',
#  cip: '35.229.120.246',
#  cua: 'python-requests/2.27.1',
#  pid: '',
#  stid: '304142',
#  gaclientid: '',
#  bkng_cookie_identifier: 'UmFuZG9tSVYkc2RlIyh9YeXKWxo4vn0nvnrzeECU48xc7H0CeafcjJhSsxtcprdp',
#  tag_cdn: 'tags.tiqcdn.com',
#  cspn: '9H2PPs8dtt8LdsG',
#  rmk_var: '-1',
#  rbda: '-1',
#  isnv: '1',
#  isrtv: '0',
#  israv: '0',
#  commaud: '-1'
#  };
#  window.dataLayer = [{
#  site: 'bookings2',
#  stypeid: '1',
#  action: 'searchresults',
#  crt: '1',
#  fbp: '1',
#  exp1: '',
#  exp2: '0',
#  bem: '0',
#  bip: '0',
#  exp_rmkt_test: 'global_on',
#  exp_google_tag_manager: '1',
#  ns: '1',
#  nsc: '0',
#  famem: '-1',
#  famfn: '-1',
#  fampn: '-1',
#  gcem: '-1',
#  gcpn: '-1',
#  gwcur: '-1',
#  gwcuc: '-1',
#  rb: '1',
#  gst: '1',
#  fbqs: '',
#  sage: '0',
#  alev: '0',
#  atid: '',
#  atnm: '',
#  biz_s: '2',
#  biz_p: '',
#  bo: '1',
#  browser: 'bot',
#  browser_ver: '0',
#  bstage: '',
#  emksho: '1',
#  is_subscribed_to_newsletter: '',
#  genis: '',
#  glev: '',
#  n_b: '',
#  sid: '90149fe82aa24bb5d2c55072c9ce38f7',
#  ui: '',
#  is_aid_mcc_level_tracked: '',
#  partner_channel_id: '3',
#  ttv: '',
#  ttv_uc: '',
#  p1: '0',
#  preferred_neighborhoods: [],
#  hotel_name: '',
#  channel_id: '3',
#  partner_id: '1',
#  ai: '304142',
#  tsmp: '1683546217',
#  adults: '-1',
#  book_window: '',
#  children: '-1',
#  district_name: '-1',
#  city_name: '-1',
#  region_name: '-1',
#  country_name: '-1',
#  currency: 'EUR',
#  date_in: '-1',
#  cul: '0',
#  mnns: '0',
#  date_out: '-1',
#  dayofwk: '-1',
#  depth: '1',
#  dest_type: '-1',
#  dest_id: '-1',
#  dest_cc: '',
#  dest_ufi: '-1',
#  dest_name: '',
#  hotel_count: '0',
#  hotel_id: '0',
#  hotel_id_list: '',
#  hr: '-1',
#  i1: '',
#  i2: '',
#  i3: '',
#  isfd: '',
#  isnl: '',
#  label: 'gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB',
#  language: 'fr',
#  logged_in: '0',
#  nights: '-1',
#  cv: '-1',
#  ordv: '-1',
#  rooms: '-1',
#  seed: 'jj5rI3DhNBdXjfsrd8H-PA',
#  sid_dyna: '006458e069517ac63e217bf5539222a743_1683545400',
#  srord: '-1',
#  sub: '0',
#  ui_a: '-1',
#  user_location: 'fr',
#  cip: '35.229.120.246',
#  cua: 'python-requests/2.27.1',
#  pid: '',
#  stid: '304142',
#  gaclientid: '',
#  bkng_cookie_identifier: 'UmFuZG9tSVYkc2RlIyh9YeXKWxo4vn0nvnrzeECU48xc7H0CeafcjJhSsxtcprdp',
#  tag_cdn: 'tags.tiqcdn.com',
#  cspn: '9H2PPs8dtt8LdsG',
#  rmk_var: '-1',
#  rbda: '-1',
#  isnv: '1',
#  isrtv: '0',
#  israv: '0',
#  commaud: '-1'
#  }] || window.dataLayer;
#  (function(a,b,c,d){
#  if (window.location.search.indexOf('gitlab_runner') > -1 || document.cookie.indexOf('gitlab_runner') > -1) return;
#  var w = window || {};
#  function loadTagContainer(){
#  if(B && B.et && B.et.stage) {
#  B.et.stage('aaTBNZZJRLESPIDNJC', 1);
#  B.et.stage('aaTBNZZJRLdQANAFQFaLESPIDNJC', 1);
#  B.et.stage('aaTBNZZJRLESPIDNJDPVBC', 1);
#  }
#  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#  j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.nonce='9H2PPs8dtt8LdsG';j.async=true;j.src=
#  'https://www.googletagmanager.com/gtm.js?id=GTM-5Q664QZ';f.parentNode.insertBefore(j,f);
#  })(window,document,'script','dataLayer', 'GTM-5Q664QZ');
#  };
#  if(w.addEventListener){
#  w.addEventListener('load', loadTagContainer, false);
#  } else if(w.attachEvent){
#  w.attachEvent('onload', loadTagContainer);
#  }
#  })();
#  </script>
#  <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5Q664QZ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
#  <div data-capla-component="b-search-web-searchresults/TravellerHeader" data-capla-namespace="b-search-web-searchresultsdRMHCECe"><div class="web-shell-header-mfe" data-testid="web-shell-header-mfe"><header class="b4ea8459d6"><nav class="c20fd9b542"><div class="f9966e6860"><div class="a945757098"><span data-testid="header-logo"><a aria-label="Booking.com" class="fc63351294" data-testid="header-booking-logo" href="https://www.booking.com/index.fr.html?aid=304142&amp;label=gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB&amp;sid=58961c85c704538c285e8b590e142b74&amp;"><svg fill="none" viewbox="0 0 180 30" xmlns="http://www.w3.org/2000/svg"><path d="M70.6 2.73999C70.602 2.19808 70.7646 1.66892 71.0673 1.21943C71.3701 0.769947 71.7993 0.420321 72.3007 0.214768C72.8021 0.00921437 73.3532 -0.0430342 73.8843 0.064629C74.4155 0.172292 74.9027 0.435032 75.2845 0.819622C75.6663 1.20421 75.9255 1.69338 76.0293 2.22527C76.133 2.75716 76.0768 3.30788 75.8676 3.80779C75.6584 4.3077 75.3056 4.73434 74.8539 5.03377C74.4022 5.3332 73.8719 5.49197 73.33 5.48999C72.9702 5.48868 72.6141 5.41651 72.2822 5.2776C71.9503 5.13869 71.649 4.93576 71.3955 4.6804C71.1419 4.42504 70.9412 4.12225 70.8047 3.78931C70.6683 3.45637 70.5987 3.09982 70.6 2.73999V2.73999ZM116.5 23.77C117.044 23.772 117.577 23.6124 118.031 23.3114C118.484 23.0104 118.838 22.5816 119.048 22.0793C119.257 21.577 119.313 21.0238 119.208 20.4897C119.103 19.9555 118.842 19.4646
#  <div class="rlt-right maps-overlay-sr-container" id="right" role="main">
#  <div data-component="arp-header">
#  <div data-capla-component="b-search-web-searchresults/HeaderDesktop" data-capla-namespace="b-search-web-searchresultsdRMHCECe"></div>
#  </div>
#  <div data-capla-component="b-search-web-searchresults/TripTypeRecommendations" data-capla-namespace="b-search-web-searchresultsdRMHCECe"></div>
#  <div data-block-id="sr_messages">
#  </div>
#  <div id="ajaxsrwrap">
#  <div class="sr_top_warnings_bui_colors" data-block-id="sr_warnings">
#  </div>
#  <div class="hotellist_wrap tracked shorten_property_block" data-block-id="hotel_list" id="search_results_table">
#  <div data-capla-project-name="search-web" data-component="genius-vip/tracking" data-service-name="searchresults" data-tracking-enabled="1"></div>
#  <div data-arp-properties-list="1">
#  <div data-capla-component="b-search-web-searchresults/PropertiesListDesktop" data-capla-namespace="b-search-web-searchresultsdRMHCECe"></div>
#  </div>
#  </div>
#  </div> <!-- /ajaxsrwrap -->
#  <div class="viewed_hotels_sr_wrapper"></div>
#  <div style="display: none;">
#  <div id="help_preferred_property">
#  Cet établissement fait partie de notre programme Partenaires Préférés. Il s'engage à fournir une expérience positive aux clients grâce à ses services de choix et à son bon rapport qualité/prix. Il est possible que cet établissement paie une commission un peu plus élevée à Booking.com pour participer au programme.
#  </div>
#  </div>
#  </div>
#  <div class="rlt-left leftsmall" id="left" role="complementary">
#  <div id="left_col_wrapper" style="z-index: 101;">
#  <div data-component="arp-searchbox">
#  <div data-capla-component="b-search-web-searchresults/SearchBoxDesktop" data-capla-namespace="b-search-web-searchresultsdRMHCECe"><form action="https://www.booking.com/searchresults.fr.html" class="a90438ad2b" method="GET"><div class="ffa9856b86 c43efd0a38 ed26a8024c" data-testid="searchbox-layout-vertical"><div class="fca8fcd83b"><div class="c8305f6688">Rechercher</div></div><div class="fca8fcd83b"><div class="f186805e02"><div class="d8eab2cf7f e2a710e162">Destination / Nom de l'établissement :</div><div class="ab090fee6e cc6f7f2b89" data-testid="destination-container" role="none"><div class="db29ecfbe2 c072c8cf10 b1f9db9109"><div class="a61cce10a1"><div class="d4e829796c"><div class="a713e2a62f"><span aria-hidden="true" class="b6dc9a9e69 ec1b6253a6 f86806591e"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M118.8 113.2l-31-31A4 4 0 0 0 85 81a44 44 0 1 0-4 4 4 4 0 0 0 1.2 2.8l31 31a4 4 0 0 0 5.6-5.7zM52 88a36 36 0 1 1 36-36 36 36 0 0 1-36 36z"></path></svg></span></div><input autocomplete="off" class="ce45093752" data-destination="1" id=":Rp5:" name="ss" placeholder="Où allez-vous ?" value=""/><div class="ade92cdb3b bd7d7270ec"></div></div></div></div><div class="a7631de79e"></div></div></div></div><div class="fca8fcd83b"><div class="d8eab2cf7f e2a710e162" data-testid="searchbox-checkin-caption">Du </div><div class="aea57a086d" data-testid="searchbox-checkin-container"><button class="d47738b911 fb1847d86a d1b7b9fc55" data-testid="date-display-field-start" type="button"><span aria-hidden="true" class="b6dc9a9e69 b859aa7e73 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M22.502 13.5v8.25a.75.75 0 0 1-.75.75h-19.5a.75.75 0 0 1-.75-.75V5.25a.75.75 0 0 1 .75-.75h19.5a.75.75 0 0 1 .75.75v8.25zm1.5 0V5.25A2.25 2.25 0 0 0 21.752 3h-19.5a2.25 2.25 0 0 0-2.25 2.25v16.5A2.25 2.25 0 0 0 2.252 24h19.5a2.25 2.25 0 0 0 2.25-2.25V13.5zm-23.25-3h22.5a.75.75 0 0 0 0-1.5H.752a.75.75 0 0 0 0 1.5zM7.502 6V.75a.75.75 0 0 0-1.5 0V6a.75.75 0 0 0 1.5 0zm10.5 0V.75a.75.75 0 0 0-1.5 0V6a.75.75 0 0 0 1.5 0z"></path></svg></span><div class="b9c5dd7ce2" data-testid="date-display-field-date-in-icon">8</div>lundi 8 mai 2023<span aria-hidden="true" class="b6dc9a9e69 f8931b3e81 e25355d3ee" data-testid="searchbox-form-button-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></button></div><div class="d8eab2cf7f e2a710e162" data-testid="searchbox-checkout-caption">Au </div><div class="aea57a086d" data-testid="searchbox-checkout-container"><button class="d47738b911 fb1847d86a a7b921c691" data-testid="date-display-field-end" type="button"><span aria-hidden="true" class="b6dc9a9e69 b859aa7e73 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M22.502 13.5v8.25a.75.75 0 0 1-.75.75h-19.5a.75.75 0 0 1-.75-.75V5.25a.75.75 0 0 1 .75-.75h19.5a.75.75 0 0 1 .75.75v8.25zm1.5 0V5.25A2.25 2.25 0 0 0 21.752 3h-19.5a2.25 2.25 0 0 0-2.25 2.25v16.5A2.25 2.25 0 0 0 2.252 24h19.5a2.25 2.25 0 0 0 2.25-2.25V13.5zm-23.25-3h22.5a.75.75 0 0 0 0-1.5H.752a.75.75 0 0 0 0 1.5zM7.502 6V.75a.75.75 0 0 0-1.5 0V6a.75.75 0 0 0 1.5 0zm10.5 0V.75a.75.75 0 0 0-1.5 0V6a.75.75 0 0 0 1.5 0z"></path></svg></span><div class="b9c5dd7ce2" data-testid="date-display-field-date-in-icon">9</div>mardi 9 mai 2023<span aria-hidden="true" class="b6dc9a9e69 f8931b3e81 e25355d3ee" data-testid="searchbox-form-button-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></button></div><div class="d8eab2cf7f e2a710e162" data-testid=" ...
#  </div>
#  <div data-component="arp-left-column">
#  <div data-capla-component="b-search-web-searchresults/LeftColumnDesktop" data-capla-namespace="b-search-web-searchresultsdRMHCECe"><div class="b546c9ed2b da7118f117"><div class="c1aac87ff7 edff2772e1 c60e80d6a6 e5c543a0db" data-testid="map-trigger" role="none"><div class="c75185f3e8"><span class="d0438f59a5" data-testid="map-entry-pin-icon"><span class="e75db87696"><span class="b56c581c9f"></span><svg class="b2873bf9cb" viewbox="-1 -1 26 32"><path d="M24 12.4286C24 19.2927 12 29 12 29C12 29 0 19.2927 0 12.4286C0 5.56446 5.37258 0 12 0C18.6274 0 24 5.56446 24 12.4286Z"></path></svg></span><svg class="ae0a00836a" viewbox="0 0 12 4"><ellipse cx="6" cy="2" rx="6" ry="2"></ellipse></svg></span></div><button class="fc63351294 a822bdf511 d4b6b7a9e7 f7db01295e c334e6f658 f4605622ad d2c52b10ce" type="button"><span class="e57ffa4eb5">Voir sur la carte</span></button></div></div><div id="popular-filters-go-here"></div></div>
#  </div>
#  </div>
#  <div aria-live="assertive" class="visuallyhidden" id="filter_a11y_live" role="status"></div>
#  <div data-block-id="filter_popup">
#  </div>
#  </div>
#  <div class="clear"></div>
#  </div> <!-- /basiclayout -->
#  <div class="bottom_of_basiclayout" style="margin-top: -20px;"></div>
#  <div class="calendar" id="calendar" style="position: absolute;"></div>
#  <div class="similar_destination sr_compset_grid track_similar_destination" id="x_sr_compset_arp" style="display: none;"></div>
#  </div>
#  <svg aria-hidden="true" class="bk-icon -streamline-arrow_nav_left" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24"><path d="M14.55 18a.74.74 0 0 1-.53-.22l-5-5A1.08 1.08 0 0 1 8.7 12a1.1 1.1 0 0 1 .3-.78l5-5a.75.75 0 0 1 1.06 0 .74.74 0 0 1 0 1.06L10.36 12l4.72 4.72a.74.74 0 0 1 0 1.06.73.73 0 0 1-.53.22zm-4.47-5.72zm0-.57z"></path></svg>
#  <svg aria-hidden="true" class="bk-icon -streamline-arrow_nav_right" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg>
#  </div>
#  </div>
#  <div class="slinks">
#  </div>
#  <div class="footerconstraint cnd-onview-anchor footer_no_lang_track a11y_fix_footer_contrast_footerconstraint" id="footer_menu_track" role="contentinfo">
#  <div aria-label="Abonnez-vous à notre newsletter pour accéder à nos meilleures offres - bas de page" class="newsletter_subscribe_with_sprites" data-emk-subscription-success-remove="" data-et-click="customGoal:cCHObTRVDEZRdPQBcGCfTKYCcZeKe:5" id="newsletter_form_footer_container" role="region">
#  <form action="https://www.booking.com/newslettersubscribe.html" class="footerForm emk-subscription-entry-point" data-component="emk/subscription-entry-point emk/subscription-entry-point-feedback-msg" data-emk-entry-point-label="footer" id="emk-footer" method="post" name="newsletterform">
#  <input name="label" type="hidden" value="gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB"/>
#  <input name="lang" type="hidden" value="fr"/>
#  <input name="sid" type="hidden" value="90149fe82aa24bb5d2c55072c9ce38f7"/>
#  <input name="url" type="hidden" value=""/>
#  <input name="hostname" type="hidden" value="www.booking.com"/>
#  <input name="companyname" type="hidden" value="Booking.com"/>
#  <input data-ajax-submit="" name="aid" type="hidden" value="304142"/>
#  <input data-ajax-submit="" name="label" type="hidden" value="gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB"/>
#  <input name="endpoint_url" type="hidden" value="https://www.booking.com/searchresults.fr.html#emk-footer"/>
#  <input name="error_url" type="hidden" value="https://www.booking.com/searchresults.fr.html#emk-footer"/>
#  <input data-ajax-submit="" name="subscribe_source" type="hidden" value="footer_searchresults"/>
#  <input data-ajax-submit="" name="opt_in" type="hidden" value="1"/>
#  <div class="emk_footer_update emk_footer_centered emk_footer_update_space">
#  <div class="footerconstraint-inner">
#  <div class="emk_footer_banner_block">
#  <h2>Gagnez du temps et de l'argent !</h2>
#  </div>
#  <div class="emk_footer_subbanner_block">
#  Inscrivez-vous et nous vous enverrons les meilleures offres
#  </div>
#  <div class="clearfix"></div>
#  <div class="emk_footer_form_layout">
#  <label class="invisible_spoken" for="newsletter_to">
#  Saisissez votre adresse e-mail et nous vous enverrons nos meilleures offres
#  </label>
#  <div class="subscription_form_wrap">
#  <input autocapitalize="off" class="input_newsletter_subscription_to" data-ajax-submit="" id="newsletter_to" name="to" placeholder="Votre adresse e-mail " required="true" title="" type="email" value=""/>
#  <button data-et-click="" id="newsletter_button_footer">
#  Abonnez-vous !
#  </button>
#  </div>
#  <div data-et-view="dLYHMRFeRQcDaIPaMNfQCcbNXGDJae:1"></div>
#  </div>
#  <p aria-live="assertive" class="emk-feedback-msg use_sprites_no_back -invalid" role="alert">
#  <span aria-hidden="true" class="bicon-close"></span>
#  <span class="invisible_spoken">Erreur :</span>
#  Veuillez saisir une adresse e-mail valide
#  </p>
#  <p aria-live="assertive" class="emk-feedback-msg use_sprites_no_back -error" role="alert">
#  <span aria-hidden="true" class="bicon-close"></span>
#  <span class="invisible_spoken">Erreur :</span>
#  Nous sommes désolés mais une erreur s'est produite.
#  </p>
#  <p aria-live="assertive" class="emk-feedback-msg use_sprites_no_back -success" role="status">
#  <span aria-hidden="true" class="bicon-checkyes"></span>
#  Merci ! Nous vous avons envoyé un e-mail pour vous permettre de terminer votre inscription.
#  </p>
#  </div>
#  <input data-ajax-submit="" name="recaptcha_enabled" type="hidden" value="1"/>
#  <script nonce="9H2PPs8dtt8LdsG">
#  window.onLoadRecaptchaV3Callback = function() {
#  grecaptcha.ready(function() {
#  grecaptcha.execute('6LfzopcUAAAAAPh4ue2iRjzP6XdxDVpwJigtlmeD', {action: 'searchresults'}).then(function(token) {
#  var target = $('[data-component*="emk/subscription-entry-point"]');
#  target.append("<input type=hidden name=recaptcha_token value=" + token +" data-ajax-submit>");
#  target.closest('form').submit(function() {
#  $('.grecaptcha-badge').show().css('visibility', 'visible');
#  });
#  });
#  });
#  };
#  </script>
#  <style nonce="9H2PPs8dtt8LdsG">.grecaptcha-badge { display: none; bottom: 90px !important; }</style>
#  <div data-component="core/recaptcha/v3" data-delay-load="load" data-key="6LfzopcUAAAAAPh4ue2iRjzP6XdxDVpwJigtlmeD" data-onload="onLoadRecaptchaV3Callback"></div>
#  </div>
#  </form>
#  </div>
#  <div style="clear: both;"></div>
#  <div class="footer-wrapper" id="booking-footer">
#  <div class="footer-top-menu" id="footer_top_menu">
#  <div class="footer-top-partners clearfix js-footer-top-menu">
#  <div class="footerconstraint-inner clearfix">
#  <div id="footertopnav-partners" role="navigation">
#  <p class="footer-top-partner-text footer-top-partner-buttons">
#  <a class="footer-top-button" data-et-click="customGoal:cCHObTRVDEZRdPQBcGCfTKYCcZeKe:4 " data-et-view="HCZEZUaNZIUONSFTUQODZEYTYeYINXGET:1" data-ga-track="click|pageview:/internallink/partner/footer/hotellink/searchresults/fr" data-qa="joinapp_ep" href="https://join.booking.com/?lang=fr&amp;aid=304142&amp;utm_source=footer_menu&amp;utm_medium=frontend&amp;label=gen000nr-10CAQoggI49ANIDVgEaE2IAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AunA46IGwAIB0gIkY2ExZDQyMzUtYjkxNC00Y2MwLTk3NDEtM2I0YWUzODdhM2Rk2AIB4AIB" ref="nofollow" target="_blank">
#  Ajoutez votre établissement
#  </a>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="footerconstraint-inner clearfix">
#  <div id="footertopnav" role="navigation">
#  <ul class="footer-top-links-list">
#  <li class="footer-top-link">
#  <a href="https://www.booking.com/searchresults.fr.html" rel="nofollow">Version mobile</a>
#  </li>
#  <li class="footer-top-link">
#  <a href="https://account.booking.com/auth/oauth2?response_type=code&amp;state=Ut4Bj4HPNTNRZc9qSNMNwsd6IFj-45WX-jLyDCOCvti1s3LpSIw9pcRMFuzsecE0wKVlo5L-1hRQf2rPDY2Bb_1KT3ru7xf9Ux54ZYZGAfVbijrqXw3hAlzw_ILnelEvd_Lx55_oLaStjGv8qqzggC9FltcSWN7j9ZiRzfDru83F-2GFHHIkyyiky60KdmbE3VguBWAhORymya_I11kCqiukSEOkSjd_RrBAr7qKph53LiEcnxaLJab-BQXWMw9rSsCR1x_0ObT0dxkUGsyaNaVtSuH_fEiucAR7qLADxEbk&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;lang=fr&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;dt=1683546217&amp;aid=304142&amp;bkng_action=searchresults">
#  Votre compte
#  </a>
#  </li>
#  <li class="footer-top-link">
#  <a class="manage" href="https://secure.booking.com/content/cs.fr.html">
#  Modification de votre réservation en ligne
#  </a>
#  </li>
#  <li class="footer-top-link" data-ga-track="click|CSIR|CS|footer_top_customer_service_help">
#  <a class="cuca" data-bui-component="Tooltip" data-ga-track="click|Click|Action: searchresults|hc_entrypoint_blue_footer" href="https://secure.booking.com/help.fr.html#/?source=blue_footer" title="Votre référence (ID)  “90149FE”">
#  Aide du Service Clients
#  </a>
#  </li>
#  <script nonce="9H2PPs8dtt8LdsG">
#  document.querySelector('.cuca').addEventListener('blur', function() {
#  window.BUI.getInstance(this, 'Tooltip').hide();
#  })
#  </script>
#  <li class="footer-top-link">
#  <a class="footer_become_affiliate" data-bui-component="Tooltip" data-ga-track="click|pageview:/internallink/partner/footer/affiliatelink/searchresults/fr" href="
#  https://www.booking.com/affiliate-program/v2/index.fr.html
#  " title="Devenir affilié">
#  Devenir affilié
#  </a>
#  <script nonce="9H2PPs8dtt8LdsG">
#  document.querySelector('.footer_become_affiliate').addEventListener('blur', function() {
#  window.BUI.getInstance(this, 'Tooltip').hide();
#  })
#  </script>
#  </li>
#  <li class="footer-top-link">
#  <a class="tracked" data-google-track="Click/Action: searchresults/BBTool Footer BBZ" href="https://business.booking.com/">Booking.com Business</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="footerconstraint-inner">
#  <div class="footer-navigation-links-wrapper clearfix" id="footer" role="navigation">
#  <div class="footer-navigation-links" id="footer_links">
#  <div class="footer-navigation-links-column footer-seo-links-to-html-sitemaps">
#  <ul class="footer-navigation-links-list">
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/country.fr.html" rel="nofollow">
#  Pays
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/region.fr.html" rel="nofollow">
#  Régions
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/city.fr.html" rel="nofollow">
#  Villes
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/district.fr.html" rel="nofollow">
#  Quartiers
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/airport.fr.html" rel="nofollow">
#  Aéroports
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/hotel/index.fr.html" rel="nofollow">
#  Hôtels
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="seoindexlinks" href="https://www.booking.com/landmark.fr.html" rel="nofollow">
#  Sites d'intérêt
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-navigation-links-column">
#  <ul class="footer-navigation-links-list footer-seo-links-to-index">
#  <li class="footer-navigation-link">
#  <a data-ga="booking-home" href="https://www.booking.com/booking-home/index.fr.html">
#  Hébergements indépendants
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="apartments" href="https://www.booking.com/apartments/index.fr.html">
#  Appartements
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="resorts" href="https://www.booking.com/resorts/index.fr.html">
#  Complexes hôteliers
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="villas" href="https://www.booking.com/villas/index.fr.html">
#  Villas
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="hostels" href="https://www.booking.com/hostels/index.fr.html">
#  Auberges de jeunesse
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="bed_and_breakfast" href="https://www.booking.com/bed-and-breakfast/index.fr.html">
#  B&amp;B / Chambres d'hôtes
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga="guest_house" href="https://www.booking.com/guest-house/index.fr.html">
#  Maisons d'hôtes
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-navigation-links-column">
#  <ul class="footer-navigation-links-list">
#  <li class="footer-navigation-link">
#  <a data-ga="accommodations" href="https://www.booking.com/accommodations.fr.html">
#  Des hébergements uniques
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a class="js-reviews-footer-link" data-ga="seoindexlinks" href="https://www.booking.com/reviews
#  .fr.html
#  ">
#  Commentaires
#  </a>
#  </li>
#  <div data-et-view="  BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe:1 BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe:3 "></div>
#  <li class="footer-navigation-link">
#  <a data-ga="extended-stays" href="https://www.booking.com/extended-stays/index.fr.html">
#  Découvrir les séjours au mois
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a category="articles-link" href="https://booking.com/articles.fr.html" location="main-site-footer" type="nav">
#  Articles
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/deals/index.fr.html" title="Offres de voyage saisonnières">
#  Offres de voyage saisonnières
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/traveller-awards/index.fr.html">
#  Traveller Review Awards
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-navigation-links-column">
#  <ul class="footer-navigation-links-list">
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/outgoinglink/traveljigsaw/fr" data-google-track="Click/Rental cars footer link click (loy_footer_rentalcars_copy: 0)/searchresults" href="http://cars.booking.com/Home.do?affiliateCode=booking-com&amp;adplat=footer&amp;preflang=fr" rel="nofollow" target="_blank">
#  Location de voitures
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/outgoinglink/kayaklink" data-google-track="Click/Kayak footer link/searchresults" href="https://booking.com/pxgo?lang=fr&amp;aid=304142&amp;url=https%3A%2F%2Fbooking.kayak.com%2Fin&amp;token=UmFuZG9tSVYkc2RlIyh9YXYkRVs_GG8E7j4ArIeJPd_njBrBqXYthmqQ3YlH482J6HiB4GJw56iBz7aCgmq0Wy7d6Z6PZYG10snhtST7kW9PF8ZKse8SvYLEhE09hDiUpN8Jp7L02RPrMF2GH_1SKUuJFojFSGIpNx5ZdE14Mjvmbweyjzsf8lCn7SOsyP1VyLBBUYnRacnq1QQYcXUm--4aZEfPzOa3RDjZLHPoQxfoekRyaMGI_PpWNd9TPR7xPRPT6mVrDv3stQX0Pk3li9DQorw7s_cdrhmoSSW_kcYT2H4GpcL8AI7slzkm_oz18Nw-JtacqhCvHkettAYk-oDx6b0yaW2s" rel="nofollow" target="_blank">
#  Comparateur de vols
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/outgoinglink/opentablelink" data-google-track="Click/Opentable footer link/searchresults" href="http://www.opentable.com?ref=16087" rel="nofollow" target="_blank">
#  Réservations de restaurant
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/internallink/partner/footer/adviserslink/searchresults/fr" href="
#  https://www.booking.com/affiliate-program/v2/index.fr.html
#  " title="Booking.com for Travel Advisers">
#  Booking.com pour les Agents de Voyage
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-navigation-links-column">
#  <ul class="footer-navigation-links-list">
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/covid-19-booking-faqs.fr.html">
#  FAQ sur le coronavirus (COVID-19)
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/content/about.fr.html">À propos de Booking.com</a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|Click|Action: searchresults|hc_entrypoint_footer_navigation" href="https://secure.booking.com/help.fr.html#/?source=footer_navigation">
#  Aide du Service Clients
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://partner.booking.com/en-gb?utm_campaign=footer_list&amp;utm_medium=frontend_footer&amp;utm_source=booking.com">
#  Aide aux partenaires
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/outgoinglink/footer/careerlink/fr" href="https://careers.booking.com/?utm_source=corporate&amp;utm_medium=footer">
#  Careers
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a data-ga-track="click|pageview:/outgoinglink/footer/sustainabilitylink/fr" href="https://sustainability.booking.com/">
#  Durabilité
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a class="tracked" data-google-track="Click/Action: about_us/press" href="https://news.booking.com/fr/">
#  Actualités presse
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a class="tracked" href="https://www.booking.com/trust-and-safety.fr.html">
#  Centre des ressources en matière de sécurité
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a class="tracked" data-google-track="Click/Action: about_us/investor_relations" href="https://www.bookingholdings.com/">
#  Relations avec les investisseurs
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/content/terms.fr.html">
#  Conditions générales d'utilisation
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://secure.booking.com/content/complaints.fr.html">
#  Réclamation partenaires
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/content/how_we_work.fr.html">
#  Fonctionnement de notre site
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.booking.com/content/privacy.fr.html">
#  Charte de confidentialité et informations sur les cookies
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <div style="display:none">
#  <button class="ot-sdk-show-settings" id="ot-sdk-btn">Cookie Settings</button>
#  </div>
#  <a class="ot-preference-center-footer" href="#">
#  Gérer les paramètres relatifs aux cookies
#  </a>
#  </li>
#  <li class="footer-navigation-link">
#  <a href="https://www.bookingholdings.com/about/compliance-and-ethics/">
#  Charte MSA
#  </a>
#  </li>
#  <li class="footer-navigation-link" data-ga-track="click|CSIR|CS|footer_link_contact_us">
#  <a href="https://www.booking.com/content/contact-us.fr.html">
#  Contacts de l'entreprise
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div></div>
#  <div aria-label="Téléchargez maintenant l'appli GRATUITE Booking.com" class="local_info_bot footerconstraint-inner" role="region"><div class="local_info_bot_inner">
#  <div class="extranet_link_container">
#  <a class="extranet_link" data-ga-track="click|Footer|Click - Extranet login|searchresults" href="https://admin.booking.com/?lang=fr&amp;utm_source=extranet_login_footer&amp;utm_medium=frontend&amp;utm_campaign=login_footer_v0">
#  Accéder à l'extranet
#  </a>
#  </div>
#  <div class="footercopyright">
#  <div class="whitebar">
#  <div class="copyright_text">
#  Copyright © 1996–2023
#  Booking.com™. Tous droits réservés.
#  </div>
#  </div>
#  </div>
#  </div>
#  <div style="clear:both;"> </div>
#  </div>
#  <div class="footer-logos footerconstraint-inner">
#  <div class="footer__priceline">
#  <p class="footer__priceline__title">Booking.com fait partie de Booking Holdings Inc., le leader mondial des voyages en ligne et services associés.</p>
#  <div class="footer__priceline__list">
#  <ul>
#  <li>
#  <img alt="Booking.com" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_booking/27c8d1832de6a3123b6ee45b59ae2f81b0d9d0d0.png" title="Booking.com" width="91"/>
#  </li>
#  <li>
#  <img alt="Priceline" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_priceline/f80e129541f2a952d470df2447373390f3dd4e44.png" title="Priceline" width="91"/>
#  </li>
#  <li>
#  <img alt="Kayak" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_kayak/83ef7122074473a6566094e957ff834badb58ce6.png" title="Kayak" width="79"/>
#  </li>
#  <li>
#  <img alt="Agoda" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_agoda/1c9191b6a3651bf030e41e99a153b64f449845ed.png" title="Agoda" width="70"/>
#  </li>
#  <li>
#  <img alt="Rentalcars" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_rentalcars/6bc5ec89d870111592a378bbe7a2086f0b01abc4.png" title="Rentalcars" width="109"/>
#  </li>
#  <li>
#  <img alt="OpenTable" height="26" src="https://cf.bstatic.com/static/img/tfl/group_logos/logo_opentable/a4b50503eda6c15773d6e61c238230eb42fb050d.png" title="OpenTable" width="95"/>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
# ...
#  <svg aria-hidden="true" class="bk-icon -streamline-landmark" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24"><path d="M4.5 8.911h3l-.75-.75v9l.75-.75h-3l.75.75v-9l-.75.75zm0-1.5a.75.75 0 0 0-.75.75v9c0 .414.336.75.75.75h3a.75.75 0 0 0 .75-.75v-9a.75.75 0 0 0-.75-.75h-3zm6 1.5h3l-.75-.75v9l.75-.75h-3l.75.75v-9l-.75.75zm0-1.5a.75.75 0 0 0-.75.75v9c0 .414.336.75.75.75h3a.75.75 0 0 0 .75-.75v-9a.75.75 0 0 0-.75-.75h-3zm6 1.5h3l-.75-.75v9l.75-.75h-3l.75.75v-9l-.75.75zm0-1.5a.75.75 0 0 0-.75.75v9c0 .414.336.75.75.75h3a.75.75 0 0 0 .75-.75v-9a.75.75 0 0 0-.75-.75h-3zm4.5 12H3l.75.75v-2.25h16.5v2.25l.75-.75zm0 1.5a.75.75 0 0 0 .75-.75v-2.25a1.5 1.5 0 0 0-1.5-1.5H3.75a1.5 1.5 0 0 0-1.5 1.5v2.25c0 .414.336.75.75.75h18zm-19.5 3h21a.75.75 0 0 0 0-1.5h-21a.75.75 0 0 0 0 1.5zm0-3h21a.75.75 0 0 0 0-1.5h-21a.75.75 0 0 0 0 1.5zm18.75-15.75v2.25H3.75v-2.25l-.415.67L12 1.5l8.665 4.332-.415-.671zm1.5 0a.75.75 0 0 0-.415-.67L12.67.157a1.503 1.503 0 0 0-1.34 0L2.666 4.49a.75.75 0 0 0-.415.671v2.25a1.5 1.5 0 0 0 1.5 1.5h16.5a1.5 1.5 0 0 0 1.5-1.5v-2.25zM3 5.911h18a.75.75 0 0 0 0-1.5H3a.75.75 0 0 0 0 1.5z"></path></svg>
#  <svg aria-hidden="true" class="bk-icon -streamline-transport_airplane_depart" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24"><path d="M18.33 3.57L5.7 9.955l.79.07-1.96-1.478a.75.75 0 0 0-.753-.087l-2.1.925C.73 9.856.359 10.967.817 11.88c.11.22.263.417.45.577l3.997 3.402a2.94 2.94 0 0 0 3.22.4l3.62-1.8-1.084-.671v5.587a1.833 1.833 0 0 0 2.654 1.657l1.88-.932a1.85 1.85 0 0 0 .975-1.226l1.87-7.839-.396.498 3.441-1.707a3.494 3.494 0 1 0-3.11-6.
-.815-.001-1.484.664-1.49 1.488a8.652 8.652 0 0 0 2.37 6.184 8.95 8.95 0 0 0 7.031 2.35.75.75 0 1 0-.158-1.49 7.431 7.431 0 0 1-5.82-1.927 7.142 7.142 0 0 1-1.923-5.091L3.426 7.1a7.746 7.746 0 0 1 4.476 1.357.75.75 0 0 0 .848-1.236zm-4.944 3.966c-2.223.948-3.808 2.716-3.808 4.441 0 3.47 5.422 6 12 6a22.404 22.404 0 0 0 6.977-1.047.75.75 0 0 0 .523-.715v-3.488l-.75.75h4.383a.75.75 0 0 0 .715-.524c.1-.315.15-.643.152-.973 0-2.068-1.986-3.858-5.079-4.944a.75.75 0 1 0-.497 1.416c2.56.898 4.076 2.265 4.076 3.525 0 .176-.028.354-.082.524l.715.226v-.75h-4.383a.75.75 0 0 0-.75.75v3.488l.523-.715a20.922 20.922 0 0 1-6.516.977c-5.856 0-10.507-2.17-10.507-4.5 0-1.02 1.17-2.325 2.896-3.061a.75.75 0 0 0-.588-1.38z"></path></svg>
#  <svg aria-hidden="true" class="bk-icon -streamline-food" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24"><path d="M5.999.75v22.5a.75.75 0 0 0 1.5 0V.75a.75.75 0 0 0-1.5 0zm3 0V7.5a2.259 2.259 0 0 1-2.252 2.25 2.258 2.258 0 0 1-2.248-2.252V.75a.75.75 0 0 0-1.5 0V7.5a3.76 3.76 0 0 0 3.748 3.75 3.76 3.76 0 0 0 3.752-3.748V.75a.75.75 0 0 0-1.5 0zm6.75 15.75h3c1.183.046 2.203-.9 2.25-2.111a2.22 2.22 0 0 0 0-.168c-.25-6.672-.828-9.78-3.231-13.533a1.508 1.508 0 0 0-2.77.81V23.25a.75.75 0 0 0 1.5 0V1.503c0 .003.001 0 .003 0a.006.006 0 0 1 .008.002c2.21 3.45 2.75 6.354 2.99 12.773v.053a.696.696 0 0 1-.721.67L15.749 15a.75.75 0 0 0 0 1.5z"></path></svg>
#  <div class="map_full_overlay__wrapper">
#  <div class="map_full_overlay__mask"></div>
#  <div aria-label="Close map" class="map_full_overlay__close" role="button" tabindex="0"></div>
#  <div class="map_with_list__container">
#  <div class="map_left_filters__container">
#  <div class="map_left_filters"></div>
#  </div>
#  <div class="map_left_cards map_left_cards--v2">
#  </div>
#  <div class="map_left_cards__collapse__button"></div>
#  <div aria-label="Map View" aria-modal="true" class="b_map_br_zoom b_map_custom_zoom map_view" id="b_map_container" role="dialog">
#  <div class="b_map_controls_container"></div>
#  <div id="js_searchbox_placeholder"></div>
#  <div id="b_map_tiles">
#  <div id="b_gmap_inner"></div>
#  <div id="b_overlay"></div>
#  <div id="map_detail_overlay"></div>
#  </div>
#  <div id="b_map_legend_html"></div>
#  </div>
#  </div>
#  </div>
#  <div style="display: none;">
#  <svg aria-hidden="true" class="bk-icon -fonticon-aclose" focusable="false" height="32" role="presentation" viewbox="0 0 36 32" width="36">
#  <path d="M34 3.2L30.8 0 18 12.8 5.2 0 2 3.2 14.8 16 2 28.8 5.2 32 18 19.2 30.8 32l3.2-3.2L21.2 16 34 3.2z"></path>
#  </svg>
#  <svg aria-hidden="true" class="bk-icon -fonticon-downchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
#  <path d="M45.1.2L25.7 19.7 6.3.2 0 6.5l25.7 25.7L51.4 6.5z"></path>
#  </svg>
#  <svg aria-hidden="true" class="bk-icon -fonticon-upchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
#  <path d="M6.3 32.2l19.4-19.5 19.4 19.5 6.3-6.3L25.7.2 0 25.9z"></path>
#  </svg>
#  <svg aria-hidden="true" class="bk-icon -fonticon-checkempty" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
#  <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z"></path>
#  </svg>
#  <svg aria-hidden="true" class="bk-icon -fonticon-checkno2" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
#  <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z"></path>
#  <path d="M24.587 11.039L13.825 21.583c-.054.09-.12.182-.208.271l-.504.505c-.278.278-.607.403-.733.276l-5.125-5.366c-.126-.126-.002-.454.276-.732l.504-.505c.279-.279.607-.403.733-.277l3.842 4.022L23.073 9.525a.715.715 0 0 1 1.009 0l.505.505a.715.715 0 0 1 0 1.009z"></path>
#  </svg>
#  </div>
#  <span id="req_info" style="display:none;">1733680,1718320,1718380,1728110,1709570,1718320|1,1720070|1,1724520,1720070,1709570|3,1724650</span>
#  </body></html>]

# %%
# Let's now Loop through all parents of link
# Let's also use enumerate() built-in function to get the index number of each iteration
for i, parent in enumerate(link.parents):
    # if we have no more parents
    if parent is None:
        print(parent)
    else:
        print("Parent {} is: {}".format(i, parent.name)) # parent.name will give only the element name as output
# Out:
# Parent 0 is: body
# Parent 1 is: html
# Parent 2 is: [document]

# %%
# Select all elements named title
soup.find_all("title")
# Out:
# [<title>
#  Booking.com
#  :
#  Résultats de votre recherche
#  .
#  Réservez votre hôtel dès maintenant !
#  </title>]

# %%
soup.find_all(id="link2")
# Out:
# [<h3 class="rlp-intro-how__title rlp-intro-how__a11y-exp-title">Tout commence par une réservation</h3>,
#  <h3 class="rlp-intro-how__title rlp-intro-how__a11y-exp-title">Puis un séjour</h3>,
#  <h3 class="rlp-intro-how__title rlp-intro-how__a11y-exp-title">Et enfin, un commentaire</h3>]

# %%
soup.find_all('#search_results_table > div:nth-child(2) > div > div > div.d4924c9e74 > div:nth-child(5)')
# Out:
# []
